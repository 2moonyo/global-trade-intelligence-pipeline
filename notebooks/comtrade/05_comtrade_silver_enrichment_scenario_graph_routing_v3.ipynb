# %%
# imports and config
from pathlib import Path
import math
import heapq
import re
import warnings 
import numpy as np
import pandas as pd
import searoute as sr
import country_converter as coco
import folium
import geopandas as gpd 
from IPython.display import display

pd.set_option("display.max_columns", 160)
pd.set_option("display.max_rows", 200)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# paths and base dimensions
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "pyproject.toml").exists() and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent

FACT_ROOT = PROJECT_ROOT / "data" / "silver" / "comtrade" / "comtrade_fact"
FACT_FILES = sorted(FACT_ROOT.rglob("ref_year=*/reporter_iso3=*/*.parquet"))

DIMENSIONS_ROOT = PROJECT_ROOT / "data" / "silver" / "comtrade" / "dimensions"
DIMENSIONS_ROOT.mkdir(parents=True, exist_ok=True)

DIM_COUNTRY_PATH = DIMENSIONS_ROOT / "dim_country.parquet"
DIM_OUTPUT_PATH = PROJECT_ROOT / "data" / "silver" / "comtrade" / "dim_trade_routes.parquet"
COUNTRY_PORT_DIM_PATH = DIMENSIONS_ROOT / "dim_country_ports.parquet"
PORT_BASIN_DIM_PATH = DIMENSIONS_ROOT / "dim_port_basin.parquet"
ROUTE_APPLICABILITY_PATH = DIMENSIONS_ROOT / "bridge_country_route_applicability.parquet"
CHOKEPOINT_DIM_PATH = DIMENSIONS_ROOT / "dim_chokepoint.parquet"
BASIN_EDGE_PATH = DIMENSIONS_ROOT / "bridge_basin_graph_edges.parquet"
BASIN_PATH_RULES_PATH = DIMENSIONS_ROOT / "bridge_port_basin_chokepoints.parquet"
TRANSHIPMENT_HUB_PATH = DIMENSIONS_ROOT / "dim_transshipment_hub.parquet"
BASIN_HUB_BRIDGE_PATH = DIMENSIONS_ROOT / "bridge_basin_default_hubs.parquet"

PORT_INDEX_PATH = PROJECT_ROOT / "ingest" / "Kaggle" / "world_port_index" / "UpdatedPub150.csv"

FULL_REBUILD_DIM_TRADE_ROUTES = True
ROUTE_SCENARIO = "default_shortest"
# supported examples:
# - default_shortest
# - suez_disrupted
# - panama_disrupted
# - cape_preferred
# - risk_avoidance

MAX_PORTS_DEFAULT = 3
MAX_PORTS_MULTI_BASIN = 8

# build a route applicability bridge from fact motCode values
if not FACT_FILES:
    raise FileNotFoundError(f"No parquet fact files found under: {FACT_ROOT}")

silver_df = pd.concat([pd.read_parquet(path) for path in FACT_FILES], ignore_index=True)

silver_grain = [
    "period",
    "reporter_iso3",
    "partner_iso3",
    "flowCode",
    "cmdCode",
    "classification_version",
    "customsCode",
    "motCode",
    "partner2Code",
]

silver_df.drop_duplicates(subset=silver_grain, inplace=True)

dim_country = pd.read_parquet(DIM_COUNTRY_PATH)

if DIM_OUTPUT_PATH.exists():
    dim_trade_routes_existing = pd.read_parquet(DIM_OUTPUT_PATH)
else:
    dim_trade_routes_existing = pd.DataFrame()


SEA_CODES = {2100}
INLAND_WATER_CODES = {2200}
UNKNOWN_CODES = {0, 9000, 9900}
NON_MARINE_CODES = {1000, 3100, 3200, 9100, 9110, 9200, 9300}
MARINE_CODES = SEA_CODES.union(INLAND_WATER_CODES)

# %%
# build dim_country_ports and dim_port_basin from World Port Index using richer basin inference
port_raw = pd.read_csv(PORT_INDEX_PATH, low_memory=False)

port_candidates = port_raw.rename(
    columns={
        "Main Port Name": "main_port_name",
        "Alternate Port Name": "alternate_port_name",
        "Country Code": "country_label",
        "World Water Body": "world_water_body",
        "Harbor Size": "harbor_size",
        "Harbor Type": "harbor_type",
        "Harbor Use": "harbor_use",
        "Facilities - Container": "fac_container",
        "Facilities - Solid Bulk": "fac_solid_bulk",
        "Facilities - Liquid Bulk": "fac_liquid_bulk",
        "Facilities - Oil Terminal": "fac_oil_terminal",
        "Facilities - LNG Terminal": "fac_lng_terminal",
        "Latitude": "latitude",
        "Longitude": "longitude",
    }
).copy()

port_candidates["port_name"] = (
    port_candidates["main_port_name"].astype("string").str.strip()
    .fillna(port_candidates["alternate_port_name"].astype("string").str.strip())
)

port_candidates["country_label"] = port_candidates["country_label"].astype("string").str.strip()
port_candidates["world_water_body"] = port_candidates["world_water_body"].astype("string").str.strip()
port_candidates["harbor_size"] = port_candidates["harbor_size"].astype("string").str.strip()
port_candidates["harbor_type"] = port_candidates["harbor_type"].astype("string").str.strip()
port_candidates["harbor_use"] = port_candidates["harbor_use"].astype("string").str.strip()

port_candidates["latitude"] = pd.to_numeric(port_candidates["latitude"], errors="coerce")
port_candidates["longitude"] = pd.to_numeric(port_candidates["longitude"], errors="coerce")

port_candidates["iso3"] = coco.convert(
    names=port_candidates["country_label"].fillna(""),
    to="ISO3",
    not_found="not found",
)
port_candidates["iso3"] = pd.Series(port_candidates["iso3"], index=port_candidates.index).replace("not found", pd.NA)

def _as_txt(value) -> str:
    if pd.isna(value):
        return ""
    return str(value).strip().lower()

def infer_port_basin(world_water_body: str, latitude: float = np.nan, longitude: float = np.nan) -> str:
    txt = _as_txt(world_water_body)

    if any(k in txt for k in ["black sea", "sea of azov"]): return "BLACK_SEA"
    if any(k in txt for k in ["mediterranean", "aegean", "adriatic", "ionian", "tyrrhenian", "ligurian"]): return "MEDITERRANEAN"
    if any(k in txt for k in ["north sea", "english channel", "bay of biscay"]): return "NORTH_ATLANTIC_EUROPE"
    if "baltic" in txt: return "BALTIC"
    if any(k in txt for k in ["persian gulf", "arabian gulf"]): return "GULF"
    if "red sea" in txt: return "RED_SEA"
    if "arabian sea" in txt: return "ARABIAN_SEA"
    if "indian ocean" in txt: return "INDIAN_OCEAN"
    if any(k in txt for k in ["south china sea", "east china sea", "yellow sea", "sea of japan"]): return "WESTERN_PACIFIC"
    if any(k in txt for k in ["north pacific ocean", "bering sea", "sea of okhotsk", "tatar strait"]): return "PACIFIC"
    if "gulf of mexico" in txt: return "NORTH_AMERICA_ATLANTIC"
    if any(k in txt for k in ["caribbean", "west indies"]): return "CARIBBEAN"
    if "south atlantic ocean" in txt: return "SOUTH_ATLANTIC"
    if "north atlantic ocean" in txt:
        if pd.notna(longitude) and longitude < -30: return "NORTH_AMERICA_ATLANTIC"
        return "ATLANTIC"
    if "atlantic ocean" in txt:
        if pd.notna(latitude) and latitude < 0: return "SOUTH_ATLANTIC"
        if pd.notna(longitude) and longitude < -30: return "NORTH_AMERICA_ATLANTIC"
        return "ATLANTIC"
    if any(k in txt for k in ["gulf of guinea", "bight of benin", "bight of bonny"]): return "WEST_AFRICA_ATLANTIC"
    if any(k in txt for k in ["mozambique channel", "somali basin"]): return "EAST_AFRICA_INDIAN"
    if any(k in txt for k in ["south pacific ocean", "humboldt current"]): return "SOUTH_AMERICA_PACIFIC"
    if any(k in txt for k in ["great lakes", "danube", "river", "lake "]): return "INLAND_WATERWAY"
    return "UNKNOWN_COASTAL"

port_candidates["port_basin"] = port_candidates.apply(
    lambda row: infer_port_basin(row["world_water_body"], row["latitude"], row["longitude"]),
    axis=1
)

size_rank = {"Very Small": 1, "Small": 2, "Medium": 3, "Large": 4}
yes_rank = {"Yes": 1, "No": 0, "Unknown": 0}

for col in ["fac_container", "fac_solid_bulk", "fac_liquid_bulk", "fac_oil_terminal", "fac_lng_terminal"]:
    port_candidates[col] = port_candidates[col].map(yes_rank).fillna(0).astype(int)

port_candidates["size_rank"] = port_candidates["harbor_size"].map(size_rank).fillna(0).astype(int)

port_candidates["port_score"] = (
    port_candidates["size_rank"] * 10
    + port_candidates["fac_container"] * 5
    + port_candidates["fac_solid_bulk"] * 4
    + port_candidates["fac_liquid_bulk"] * 4
    + port_candidates["fac_oil_terminal"] * 6
    + port_candidates["fac_lng_terminal"] * 6
)

# ---------------------------------------------------------
# NEW: directional corridor fit scores
# ---------------------------------------------------------
def eastbound_corridor_fit(row) -> float:
    basin = row["port_basin"]
    iso3 = row["iso3"]
    score = 0.0

    if basin == "MEDITERRANEAN":
        score += 10.0
    elif basin == "BLACK_SEA":
        score += 6.0
    elif basin == "NORTH_ATLANTIC_EUROPE":
        score -= 4.0
    elif basin == "ATLANTIC":
        score -= 6.0

    # country-specific nudges
    if iso3 == "FRA" and basin == "MEDITERRANEAN":
        score += 3.0
    if iso3 == "ESP" and basin == "MEDITERRANEAN":
        score += 2.0

    return score


def atlantic_corridor_fit(row) -> float:
    basin = row["port_basin"]
    iso3 = row["iso3"]
    score = 0.0

    if basin in {"NORTH_ATLANTIC_EUROPE", "ATLANTIC"}:
        score += 10.0
    elif basin == "MEDITERRANEAN":
        score -= 3.0

    if iso3 == "FRA" and basin == "NORTH_ATLANTIC_EUROPE":
        score += 2.0

    return score


port_candidates["eastbound_corridor_fit"] = port_candidates.apply(eastbound_corridor_fit, axis=1)
port_candidates["atlantic_corridor_fit"] = port_candidates.apply(atlantic_corridor_fit, axis=1)

usable_ports = (
    port_candidates
    .dropna(subset=["iso3", "port_name", "latitude", "longitude"])
    .drop_duplicates(subset=["iso3", "port_name", "latitude", "longitude"])
    .copy()
)

# ---------------------------------------------------------
# DYNAMIC MULTI-BASIN & MEGA-PORT SELECTION 
# ---------------------------------------------------------

# 1. Get Top 2 ports per Basin (Guarantees coastal diversity for RUS, USA, CAN, etc.)
ranked_by_basin = usable_ports.sort_values(
    ["iso3", "port_basin", "port_score", "size_rank", "port_name"],
    ascending=[True, True, False, False, True]
).copy()
ranked_by_basin["basin_rank"] = ranked_by_basin.groupby(["iso3", "port_basin"]).cumcount() + 1
diverse_ports = ranked_by_basin[ranked_by_basin["basin_rank"] <= 2].copy()

# 2. Get Top 5 ports Overall per Country (Guarantees mega-exporters like CHN, NLD get enough capacity)
ranked_overall = usable_ports.sort_values(
    ["iso3", "port_score", "size_rank", "port_name"],
    ascending=[True, False, False, True]
).copy()
ranked_overall["overall_rank"] = ranked_overall.groupby("iso3").cumcount() + 1
mega_ports = ranked_overall[ranked_overall["overall_rank"] <= 5].copy()

# 3. Combine sets and deduplicate 
combined_ports = pd.concat([diverse_ports, mega_ports]).drop_duplicates(subset=["iso3", "port_name"])

# 4. Re-apply a clean port_rank for the final dimension table
combined_ports = combined_ports.sort_values(
    ["iso3", "port_score", "size_rank", "port_name"],
    ascending=[True, False, False, True]
).copy()
combined_ports["port_rank"] = combined_ports.groupby("iso3").cumcount() + 1
# ---------------------------------------------------------

dim_country_ports = combined_ports[
    [
        "iso3", "port_name", "latitude", "longitude", "world_water_body", "port_basin",
        "harbor_size", "harbor_type", "harbor_use", "fac_container", "fac_solid_bulk",
        "fac_liquid_bulk", "fac_oil_terminal", "fac_lng_terminal", "port_score", "port_rank",
        "eastbound_corridor_fit", "atlantic_corridor_fit",
    ]
].copy()

dim_port_basin = (
    dim_country_ports[["port_basin", "world_water_body"]]
    .drop_duplicates()
    .sort_values(["port_basin", "world_water_body"])
    .copy()
)

dim_country_ports.to_parquet(COUNTRY_PORT_DIM_PATH, index=False)
dim_port_basin.to_parquet(PORT_BASIN_DIM_PATH, index=False)

display(dim_country_ports.head(20))
display(
    dim_country_ports.loc[dim_country_ports["iso3"].isin(["USA", "CHN", "RUS", "NLD", "FRA", "ESP"])]
    .sort_values(["iso3", "port_rank"])
)
# Out:
# Wake Island not found in regex
# Johnson Atoll not found in regex
# Midway Islands not found in regex
#  not found in regex
#  not found in regex
#  not found in regex
#  not found in regex
#      iso3                    port_name   latitude  longitude  \
# 563   ABW           Sint Nicolaas Baai  12.433333 -69.916667
# 3146  ABW  Paarden Baai - (Oranjestad)  12.516667 -70.033333
# 512   AGO                      Cabinda  -5.533333  12.200000
# 1783  AGO            Estrela Oil Field  -6.450000  12.400000
# 281   AGO                       Lobito -12.333333  13.566667
# 2523  AGO                       Luanda  -8.800000  13.250000
# 1331  AGO         Malongo Oil Terminal  -5.433333  12.083333
# 1416  ALB                       Durres  41.316667  19.450000
# 2726  ALB                     Shengjin  41.816667  19.600000
# 2638  ALB                       Vlores  40.466667  19.500000
# 546   ARE               Mina Jabal Ali  25.016667  55.050000
# 3033  ARE                  Al Fujayrah  25.173056  56.369167
# 2457  ARE                 Khawr Fakkan  25.362778  56.368889
# 1887  ARE                     Abu Zaby  24.500000  54.333333
# 2242  ARE       Jabal Az Zannah/ruways  24.200000  52.700000
# 515   ARG                 Buenos Aires -34.600000 -58.366667
# 514   ARG                     La Plata -34.833333 -57.883333
# 1953  ARG                      Rosario -32.950000 -60.633333
# 2022  ARG                      Campana -34.150000 -58.966667
# 1540  ARG       Concepcion Del Uruguay -32.483333 -58.233333
#
#                                        world_water_body      port_basin  \
# 563                 Caribbean Sea; North Atlantic Ocean       CARIBBEAN
# 3146                Caribbean Sea; North Atlantic Ocean       CARIBBEAN
# 512                                South Atlantic Ocean  SOUTH_ATLANTIC
# 1783                               South Atlantic Ocean  SOUTH_ATLANTIC
# 281                                South Atlantic Ocean  SOUTH_ATLANTIC
# 2523                               South Atlantic Ocean  SOUTH_ATLANTIC
# 1331                               South Atlantic Ocean  SOUTH_ATLANTIC
# 1416  Adriatic Sea; Mediterranean Sea; North Atlanti...   MEDITERRANEAN
# 2726  Adriatic Sea; Mediterranean Sea; North Atlanti...   MEDITERRANEAN
# 2638  Adriatic Sea; Mediterranean Sea; North Atlanti...   MEDITERRANEAN
# 546                          Persian Gulf; Indian Ocean            GULF
# 3033                         Gulf of Oman; Indian Ocean    INDIAN_OCEAN
# 2457                         Gulf of Oman; Indian Ocean    INDIAN_OCEAN
# 1887                         Persian Gulf; Indian Ocean            GULF
# 2242                         Persian Gulf; Indian Ocean            GULF
# 515               Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
# 514               Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
# 1953              Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
# 2022              Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
# 1540              Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
#
#      harbor_size           harbor_type harbor_use  fac_container  \
# 563        Small  Coastal (Breakwater)    Unknown              0
# 3146  Very Small  Coastal (Breakwater)    Unknown              0
# 512        Small        Open Roadstead    Unknown              0
# 1783       Small        Open Roadstead    Unknown              0
# 281        Small     Coastal (Natural)    Unknown              0
# 2523       Small     Coastal (Natural)    Unknown              0
# 1331       Small        Open Roadstead    Unknown              0
# 1416       Small  Coastal (Breakwater)    Unknown              0
# 2726  Very Small     Coastal (Natural)    Unknown              0
# 2638  Very Small     Coastal (Natural)    Unknown              0
# 546        Large  Coastal (Breakwater)    Unknown              0
# 3033       Small  Coastal (Breakwater)      Cargo              1
# 2457      Medium     Coastal (Natural)    Unknown              1
# 1887      Medium  Coastal (Breakwater)    Unknown              0
# 2242      Medium  Coastal (Breakwater)    Unknown              0
# 515        Large  Coastal (Breakwater)    Unknown              0
# 514       Medium        River (Basins)    Unknown              0
# 1953      Medium       River (Natural)    Unknown              0
# 2022       Small       River (Natural)    Unknown              0
# 1540       Small       River (Natural)    Unknown              0
#
#       fac_solid_bulk  fac_liquid_bulk  fac_oil_terminal  fac_lng_terminal  \
# 563                0                0                 0                 0
# 3146               0                0                 0                 0
# 512                0                0                 0                 0
# 1783               0                0                 0                 0
# 281                0                0                 0                 0
# 2523               0                0                 0                 0
# 1331               0                0                 0                 0
# 1416               0                0                 0                 0
# 2726               0                0                 0                 0
# 2638               0                0                 0                 0
# 546                0                0                 0                 0
# 3033               1                1                 1                 0
# 2457               0                0                 0                 0
# 1887               0                0                 0                 0
# 2242               0                0                 0                 0
# 515                0                0                 0                 0
# 514                0                0                 0                 0
# 1953               0                0                 0                 0
# 2022               0                0                 0                 0
# 1540               0                0                 0                 0
#
#       port_score  port_rank  eastbound_corridor_fit  atlantic_corridor_fit
# 563           20          1                     0.0                    0.0
# 3146          10          2                     0.0                    0.0
# 512           20          1                     0.0                    0.0
# 1783          20          2                     0.0                    0.0
# 281           20          3                     0.0                    0.0
# 2523          20          4                     0.0                    0.0
# 1331          20          5                     0.0                    0.0
# 1416          20          1                    10.0                   -3.0
# 2726          10          2                    10.0                   -3.0
# 2638          10          3                    10.0                   -3.0
# 546           40          1                     0.0                    0.0
# 3033          39          2                     0.0                    0.0
# 2457          35          3                     0.0                    0.0
# 1887          30          4                     0.0                    0.0
# 2242          30          5                     0.0                    0.0
# 515           40          1                     0.0                    0.0
# 514           30          2                     0.0                    0.0
# 1953          30          3                     0.0                    0.0
# 2022          20          4                     0.0                    0.0
# 1540          20          5                     0.0                    0.0
#      iso3                    port_name   latitude   longitude  \
# 271   CHN                       Dalian  38.916667  121.666667
# 1807  CHN            Lon Shui Terminal  20.833333  115.683333
# 674   CHN                 Qingdao Gang  36.033333  120.266667
# 2829  CHN                     Shanghai  31.216667  121.500000
# 2846  CHN             Tianjin Xin Gang  38.966667  117.833333
# 2506  CHN                       Xiamen  24.450000  118.066667
# 679   CHN                     Quanzhou  24.883333  118.600000
# 1430  ESP                    Barcelona  41.350000    2.166667
# 1604  ESP                   Las Palmas  28.150000  -15.416667
# 2687  ESP                    Tarragona  41.100000    1.233333
# 357   ESP                     Alicante  38.333333   -0.483333
# 703   ESP                        Cadiz  36.533333   -6.300000
# 2616  ESP             Puerto De Bilbao  43.350000   -3.050000
# 1344  ESP            Puerto De Pasajes  43.333333   -1.933333
# 2463  FRA                Rade De Brest  48.383333   -4.500000
# 2512  FRA                      Lorient  47.750000   -3.350000
# 1462  FRA                     Bordeaux  44.866667   -0.566667
# 2117  FRA             Port Of Le Havre  49.483333    0.116667
# 2128  FRA                Port Of Rouen  49.450000    1.066667
# 381   FRA                       Toulon  43.100000    5.916667
# 1851  FRA                       Cannes  43.550000    7.016667
# 118   FRA              Baie Du Marigot  18.066667  -63.083333
# 1451  NLD                    Amsterdam  52.366667    4.900000
# 2599  NLD                    Rotterdam  51.900000    4.483333
# 914   NLD                    Dordrecht  51.816667    4.650000
# 1596  NLD                    Europoort  51.950000    4.116667
# 2721  NLD                    Terneuzen  51.350000    3.816667
# 2454  RUS                  Vladivostok  43.108889  131.888333
# 2538  RUS                  Kaliningrad  54.700000   20.483333
# 3613  RUS                       Vyborg  60.716667   28.750000
# 1354  RUS                     Murmansk  68.983333   33.050000
# 909   RUS                 Novorossiysk  44.716667   37.783333
# 3248  RUS                 Arkhangels'k  64.529722   40.521667
# 2470  RUS                    De Kastri  51.466667  140.783333
# 980   RUS  Aleksandrovsk -Sakhalinskiy  50.900000  142.133333
# 2495  RUS                     Nakhodka  42.800000  132.883333
# 985   RUS               Rostov-Na-Donu  47.166667   39.716667
# 1046  USA                    Baltimore  39.266667  -76.583333
# 1459  USA                       Boston  42.350000  -71.050000
# 1352  USA                     Brooklyn  40.666667  -74.016667
# 237   USA                      Buffalo  42.883333  -78.883333
# 1048  USA                      Chester  39.850000  -75.350000
# 2452  USA                    Cleveland  41.500000  -81.716667
# 468   USA                  Los Angeles  33.750000 -118.250000
# 1205  USA                      Oakland  37.816667 -122.333333
# 2307  USA                       Barrow  71.283333 -156.783333
# 1592  USA               Bernard Harbor  70.133333 -143.633333
#
#                                        world_water_body  \
# 271                     Yellow Sea; North Pacific Ocean
# 1807               South China Sea; North Pacific Ocean
# 674                     Yellow Sea; North Pacific Ocean
# 2829                East China Sea; North Pacific Ocean
# 2846            Bo Hai; Yellow Sea; North Pacific Ocean
# 2506                 Taiwan Strait; North Pacific Ocean
# 679                  Taiwan Strait; North Pacific Ocean
# 1430            Mediterranean Sea; North Atlantic Ocean
# 1604                               North Atlantic Ocean
# 2687  Balearic Sea; Mediterranean Sea; North Atlanti...
# 357             Mediterranean Sea; North Atlantic Ocean
# 703                                North Atlantic Ocean
# 2616                Bay of Biscay; North Atlantic Ocean
# 1344                Bay of Biscay; North Atlantic Ocean
# 2463                               North Atlantic Ocean
# 2512                Bay of Biscay; North Atlantic Ocean
# 1462                Bay of Biscay; North Atlantic Ocean
# 2117              English Channel; North Atlantic Ocean
# 2128              English Channel; North Atlantic Ocean
# 381             Mediterranean Sea; North Atlantic Ocean
# 1851            Mediterranean Sea; North Atlantic Ocean
# 118                 Caribbean Sea; North Atlantic Ocean
# 1451                    North Sea; North Atlantic Ocean
# 2599                    North Sea; North Atlantic Ocean
# 914                     North Sea; North Atlantic Ocean
# 1596                    North Sea; North Atlantic Ocean
# 2721                    North Sea; North Atlantic Ocean
# 2454                  Sea of Japan; North Pacific Ocean
# 2538                   Baltic Sea; North Atlantic Ocean
# 3613  Gulf of Finland; Baltic Sea; North Atlantic Ocean
# 1354                          Barents Sea; Arctic Ocean
# 909                     Black Sea; North Atlantic Ocean
# 3248               White Sea; Barents Sea; Arctic Ocean
# 2470                  Tatar Strait; North Pacific Ocean
# 980                   Tatar Strait; North Pacific Ocean
# 2495                  Sea of Japan; North Pacific Ocean
# 985        Sea of Azov; Black Sea; North Atlantic Ocean
# 1046                               North Atlantic Ocean
# 1459                               North Atlantic Ocean
# 1352                               North Atlantic Ocean
# 237                              Lake Erie; Great Lakes
# 1048                               North Atlantic Ocean
# 2452                             Lake Erie; Great Lakes
# 468                                 North Pacific Ocean
# 1205                                North Pacific Ocean
# 2307                                       Arctic Ocean
# 1592                         Beaufort Sea; Arctic Ocean
#
#                   port_basin harbor_size           harbor_type harbor_use  \
# 271          WESTERN_PACIFIC       Large  Coastal (Breakwater)    Unknown
# 1807         WESTERN_PACIFIC       Large        Open Roadstead    Unknown
# 674          WESTERN_PACIFIC       Large        Open Roadstead    Unknown
# 2829         WESTERN_PACIFIC       Large       River (Natural)    Unknown
# 2846         WESTERN_PACIFIC       Large       River (Natural)    Unknown
# 2506                 PACIFIC      Medium       River (Natural)    Unknown
# 679                  PACIFIC       Small     Coastal (Natural)    Unknown
# 1430           MEDITERRANEAN       Large  Coastal (Breakwater)    Unknown
# 1604                ATLANTIC       Large  Coastal (Breakwater)    Unknown
# 2687           MEDITERRANEAN       Large  Coastal (Breakwater)    Unknown
# 357            MEDITERRANEAN      Medium  Coastal (Breakwater)    Unknown
# 703                 ATLANTIC      Medium  Coastal (Breakwater)    Unknown
# 2616   NORTH_ATLANTIC_EUROPE      Medium  Coastal (Breakwater)    Unknown
# 1344   NORTH_ATLANTIC_EUROPE      Medium       River (Natural)    Unknown
# 2463                ATLANTIC       Large  Coastal (Breakwater)   Military
# 2512   NORTH_ATLANTIC_EUROPE      Medium       River (Natural)    Unknown
# 1462   NORTH_ATLANTIC_EUROPE       Large    River (Tide Gates)    Unknown
# 2117   NORTH_ATLANTIC_EUROPE       Large    River (Tide Gates)    Unknown
# 2128   NORTH_ATLANTIC_EUROPE       Large       River (Natural)    Unknown
# 381            MEDITERRANEAN       Large  Coastal (Breakwater)    Unknown
# 1851           MEDITERRANEAN       Small     Coastal (Natural)    Unknown
# 118                CARIBBEAN  Very Small        Open Roadstead    Unknown
# 1451   NORTH_ATLANTIC_EUROPE       Large         Canal or Lake    Unknown
# 2599   NORTH_ATLANTIC_EUROPE       Large        River (Basins)    Unknown
# 914    NORTH_ATLANTIC_EUROPE      Medium       River (Natural)    Unknown
# 1596   NORTH_ATLANTIC_EUROPE      Medium         Canal or Lake    Unknown
# 2721   NORTH_ATLANTIC_EUROPE      Medium    River (Tide Gates)    Unknown
# 2454         WESTERN_PACIFIC       Large     Coastal (Natural)      Cargo
# 2538                  BALTIC      Medium        River (Basins)    Unknown
# 3613                  BALTIC      Medium     Coastal (Natural)    Unknown
# 1354         UNKNOWN_COASTAL       Large       River (Natural)    Unknown
# 909                BLACK_SEA       Large  Coastal (Breakwater)    Unknown
# 3248         UNKNOWN_COASTAL      Medium       River (Natural)    Unknown
# 2470                 PACIFIC      Medium     Coastal (Natural)    Unknown
# 980                  PACIFIC       Small        Open Roadstead    Unknown
# 2495         WESTERN_PACIFIC       Small     Coastal (Natural)    Unknown
# 985                BLACK_SEA       Small        River (Basins)    Unknown
# 1046  NORTH_AMERICA_ATLANTIC       Large       River (Natural)    Unknown
# 1459  NORTH_AMERICA_ATLANTIC       Large     Coastal (Natural)    Unknown
# 1352  NORTH_AMERICA_ATLANTIC       Large       River (Natural)    Unknown
# 237          INLAND_WATERWAY       Large  Coastal (Breakwater)    Unknown
# 1048  NORTH_AMERICA_ATLANTIC       Large       River (Natural)    Unknown
# 2452         INLAND_WATERWAY       Large  Coastal (Breakwater)    Unknown
# 468                  PACIFIC       Large  Coastal (Breakwater)    Unknown
# 1205                 PACIFIC       Large     Coastal (Natural)    Unknown
# 2307         UNKNOWN_COASTAL  Very Small        Open Roadstead    Unknown
# 1592         UNKNOWN_COASTAL  Very Small        Open Roadstead    Unknown
#
#       fac_container  fac_solid_bulk  fac_liquid_bulk  fac_oil_terminal  \
# 271               0               0                0                 0
# 1807              0               0                0                 0
# 674               0               0                0                 0
# 2829              0               0                0                 0
# 2846              0               0                0                 0
# 2506              0               0                0                 0
# 679               0               0                0                 0
# 1430              0               0                0                 0
# 1604              0               0                0                 0
# 2687              0               0                0                 0
# 357               0               0                0                 0
# 703               0               0                0                 0
# 2616              0               0                0                 0
# 1344              0               0                0                 0
# 2463              1               1                1                 1
# 2512              1               1                1                 1
# 1462              0               0                0                 0
# 2117              0               0                0                 0
# 2128              0               0                0                 0
# 381               0               0                0                 0
# 1851              0               0                0                 0
# 118               0               0                0                 0
# 1451              0               0                0                 0
# 2599              0               0                0                 0
# 914               0               0                0                 0
# 1596              0               0                0                 0
# 2721              0               0                0                 0
# 2454              1               1                1                 1
# 2538              1               1                1                 0
# 3613              1               1                1                 0
# 1354              0               0                0                 0
# 909               0               0                0                 0
# 3248              0               0                0                 0
# 2470              0               0                0                 0
# 980               0               0                0                 0
# 2495              0               0                0                 0
# 985               0               0                0                 0
# 1046              0               0                0                 0
# 1459              0               0                0                 0
# 1352              0               0                0                 0
# 237               0               0                0                 0
# 1048              0               0                0                 0
# 2452              0               0                0                 0
# 468               0               0                0                 0
# 1205              0               0                0                 0
# 2307              0               0                0                 0
# 1592              0               0                0                 0
#
#       fac_lng_terminal  port_score  port_rank  eastbound_corridor_fit  \
# 271                  0          40          1                     0.0
# 1807                 0          40          2                     0.0
# 674                  0          40          3                     0.0
# 2829                 0          40          4                     0.0
# 2846                 0          40          5                     0.0
# 2506                 0          30          6                     0.0
# 679                  0          20          7                     0.0
# 1430                 0          40          1                    12.0
# 1604                 0          40          2                    -6.0
# 2687                 0          40          3                    12.0
# 357                  0          30          4                    12.0
# 703                  0          30          5                    -6.0
# 2616                 0          30          6                    -4.0
# 1344                 0          30          7                    -4.0
# 2463                 0          59          1                    -6.0
# 2512                 0          49          2                    -4.0
# 1462                 0          40          3                    -4.0
# 2117                 0          40          4                    -4.0
# 2128                 0          40          5                    -4.0
# 381                  0          40          6                    13.0
# 1851                 0          20          7                    13.0
# 118                  0          10          8                     0.0
# 1451                 0          40          1                    -4.0
# 2599                 0          40          2                    -4.0
# 914                  0          30          3                    -4.0
# 1596                 0          30          4                    -4.0
# 2721                 0          30          5                    -4.0
# 2454                 0          59          1                     0.0
# 2538                 0          43          2                     0.0
# 3613                 0          43          3                     0.0
# 1354                 0          40          4                     0.0
# 909                  0          40          5                     6.0
# 3248                 0          30          6                     0.0
# 2470                 0          30          7                     0.0
# 980                  0          20          8                     0.0
# 2495                 0          20          9                     0.0
# 985                  0          20         10                     6.0
# 1046                 0          40          1                     0.0
# 1459                 0          40          2                     0.0
# 1352                 0          40          3                     0.0
# 237                  0          40          4                     0.0
# 1048                 0          40          5                     0.0
# 2452                 0          40          6                     0.0
# 468                  0          40          7                     0.0
# 1205                 0          40          8                     0.0
# 2307                 0          10          9                     0.0
# 1592                 0          10         10                     0.0
#
#       atlantic_corridor_fit
# 271                     0.0
# 1807                    0.0
# 674                     0.0
# 2829                    0.0
# 2846                    0.0
# 2506                    0.0
# 679                     0.0
# 1430                   -3.0
# 1604                   10.0
# 2687                   -3.0
# 357                    -3.0
# 703                    10.0
# 2616                   10.0
# 1344                   10.0
# 2463                   10.0
# 2512                   12.0
# 1462                   12.0
# 2117                   12.0
# 2128                   12.0
# 381                    -3.0
# 1851                   -3.0
# 118                     0.0
# 1451                   10.0
# 2599                   10.0
# 914                    10.0
# 1596                   10.0
# 2721                   10.0
# 2454                    0.0
# 2538                    0.0
# 3613                    0.0
# 1354                    0.0
# 909                     0.0
# 3248                    0.0
# 2470                    0.0
# 980                     0.0
# 2495                    0.0
# 985                     0.0
# 1046                    0.0
# 1459                    0.0
# 1352                    0.0
# 237                     0.0
# 1048                    0.0
# 2452                    0.0
# 468                     0.0
# 1205                    0.0
# 2307                    0.0
# 1592                    0.0

# %%
# build dim_country_ports and dim_port_basin from World Port Index using richer basin inference
port_raw = pd.read_csv(PORT_INDEX_PATH, low_memory=False)

port_candidates = port_raw.rename(
    columns={
        "Main Port Name": "main_port_name",
        "Alternate Port Name": "alternate_port_name",
        "Country Code": "country_label",
        "World Water Body": "world_water_body",
        "Harbor Size": "harbor_size",
        "Harbor Type": "harbor_type",
        "Harbor Use": "harbor_use",
        "Facilities - Container": "fac_container",
        "Facilities - Solid Bulk": "fac_solid_bulk",
        "Facilities - Liquid Bulk": "fac_liquid_bulk",
        "Facilities - Oil Terminal": "fac_oil_terminal",
        "Facilities - LNG Terminal": "fac_lng_terminal",
        "Latitude": "latitude",
        "Longitude": "longitude",
    }
).copy()

port_candidates["port_name"] = (
    port_candidates["main_port_name"].astype("string").str.strip()
    .fillna(port_candidates["alternate_port_name"].astype("string").str.strip())
)

port_candidates["country_label"] = port_candidates["country_label"].astype("string").str.strip()
port_candidates["world_water_body"] = port_candidates["world_water_body"].astype("string").str.strip()
port_candidates["harbor_size"] = port_candidates["harbor_size"].astype("string").str.strip()
port_candidates["harbor_type"] = port_candidates["harbor_type"].astype("string").str.strip()
port_candidates["harbor_use"] = port_candidates["harbor_use"].astype("string").str.strip()

port_candidates["latitude"] = pd.to_numeric(port_candidates["latitude"], errors="coerce")
port_candidates["longitude"] = pd.to_numeric(port_candidates["longitude"], errors="coerce")

port_candidates["iso3"] = coco.convert(
    names=port_candidates["country_label"].fillna(""),
    to="ISO3",
    not_found="not found",
)
port_candidates["iso3"] = pd.Series(port_candidates["iso3"], index=port_candidates.index).replace("not found", pd.NA)

def _as_txt(value) -> str:
    if pd.isna(value):
        return ""
    return str(value).strip().lower()

def infer_port_basin(world_water_body: str, latitude: float = np.nan, longitude: float = np.nan) -> str:
    txt = _as_txt(world_water_body)

    if any(k in txt for k in ["black sea", "sea of azov"]): return "BLACK_SEA"
    if any(k in txt for k in ["mediterranean", "aegean", "adriatic", "ionian", "tyrrhenian", "ligurian"]): return "MEDITERRANEAN"
    if any(k in txt for k in ["north sea", "english channel", "bay of biscay"]): return "NORTH_ATLANTIC_EUROPE"
    if "baltic" in txt: return "BALTIC"
    if any(k in txt for k in ["persian gulf", "arabian gulf"]): return "GULF"
    if "red sea" in txt: return "RED_SEA"
    if "arabian sea" in txt: return "ARABIAN_SEA"
    if "indian ocean" in txt: return "INDIAN_OCEAN"
    if any(k in txt for k in ["south china sea", "east china sea", "yellow sea", "sea of japan"]): return "WESTERN_PACIFIC"
    if any(k in txt for k in ["north pacific ocean", "bering sea", "sea of okhotsk", "tatar strait"]): return "PACIFIC"
    if "gulf of mexico" in txt: return "NORTH_AMERICA_ATLANTIC"
    if any(k in txt for k in ["caribbean", "west indies"]): return "CARIBBEAN"
    if "south atlantic ocean" in txt: return "SOUTH_ATLANTIC"
    if "north atlantic ocean" in txt:
        if pd.notna(longitude) and longitude < -30: return "NORTH_AMERICA_ATLANTIC"
        return "ATLANTIC"
    if "atlantic ocean" in txt:
        if pd.notna(latitude) and latitude < 0: return "SOUTH_ATLANTIC"
        if pd.notna(longitude) and longitude < -30: return "NORTH_AMERICA_ATLANTIC"
        return "ATLANTIC"
    if any(k in txt for k in ["gulf of guinea", "bight of benin", "bight of bonny"]): return "WEST_AFRICA_ATLANTIC"
    if any(k in txt for k in ["mozambique channel", "somali basin"]): return "EAST_AFRICA_INDIAN"
    if any(k in txt for k in ["south pacific ocean", "humboldt current"]): return "SOUTH_AMERICA_PACIFIC"
    if any(k in txt for k in ["great lakes", "danube", "river", "lake "]): return "INLAND_WATERWAY"
    return "UNKNOWN_COASTAL"

port_candidates["port_basin"] = port_candidates.apply(
    lambda row: infer_port_basin(row["world_water_body"], row["latitude"], row["longitude"]),
    axis=1
)

size_rank = {"Very Small": 1, "Small": 2, "Medium": 3, "Large": 4}
yes_rank = {"Yes": 1, "No": 0, "Unknown": 0}

for col in ["fac_container", "fac_solid_bulk", "fac_liquid_bulk", "fac_oil_terminal", "fac_lng_terminal"]:
    port_candidates[col] = port_candidates[col].map(yes_rank).fillna(0).astype(int)

port_candidates["size_rank"] = port_candidates["harbor_size"].map(size_rank).fillna(0).astype(int)

port_candidates["port_score"] = (
    port_candidates["size_rank"] * 10
    + port_candidates["fac_container"] * 5
    + port_candidates["fac_solid_bulk"] * 4
    + port_candidates["fac_liquid_bulk"] * 4
    + port_candidates["fac_oil_terminal"] * 6
    + port_candidates["fac_lng_terminal"] * 6
)

usable_ports = (
    port_candidates
    .dropna(subset=["iso3", "port_name", "latitude", "longitude"])
    .drop_duplicates(subset=["iso3", "port_name", "latitude", "longitude"])
    .copy()
)

# ---------------------------------------------------------
# DYNAMIC MULTI-BASIN & MEGA-PORT SELECTION 
# ---------------------------------------------------------

# 1. Get Top 2 ports per Basin (Guarantees coastal diversity for RUS, USA, CAN, etc.)
ranked_by_basin = usable_ports.sort_values(
    ["iso3", "port_basin", "port_score", "size_rank", "port_name"],
    ascending=[True, True, False, False, True]
).copy()
ranked_by_basin["basin_rank"] = ranked_by_basin.groupby(["iso3", "port_basin"]).cumcount() + 1
diverse_ports = ranked_by_basin[ranked_by_basin["basin_rank"] <= 2].copy()

# 2. Get Top 5 ports Overall per Country (Guarantees mega-exporters like CHN, NLD get enough capacity)
ranked_overall = usable_ports.sort_values(
    ["iso3", "port_score", "size_rank", "port_name"],
    ascending=[True, False, False, True]
).copy()
ranked_overall["overall_rank"] = ranked_overall.groupby("iso3").cumcount() + 1
mega_ports = ranked_overall[ranked_overall["overall_rank"] <= 5].copy()

# 3. Combine sets and deduplicate 
combined_ports = pd.concat([diverse_ports, mega_ports]).drop_duplicates(subset=["iso3", "port_name"])

# 4. Re-apply a clean port_rank for the final dimension table
combined_ports = combined_ports.sort_values(
    ["iso3", "port_score", "size_rank", "port_name"],
    ascending=[True, False, False, True]
).copy()
combined_ports["port_rank"] = combined_ports.groupby("iso3").cumcount() + 1
# ---------------------------------------------------------

dim_country_ports = combined_ports[
    [
        "iso3", "port_name", "latitude", "longitude", "world_water_body", "port_basin",
        "harbor_size", "harbor_type", "harbor_use", "fac_container", "fac_solid_bulk",
        "fac_liquid_bulk", "fac_oil_terminal", "fac_lng_terminal", "port_score", "port_rank"
    ]
].copy()

dim_port_basin = (
    dim_country_ports[["port_basin", "world_water_body"]]
    .drop_duplicates()
    .sort_values(["port_basin", "world_water_body"])
    .copy()
)

dim_country_ports.to_parquet(COUNTRY_PORT_DIM_PATH, index=False)
dim_port_basin.to_parquet(PORT_BASIN_DIM_PATH, index=False)

display(dim_country_ports.head(20))
display(dim_country_ports.loc[dim_country_ports["iso3"].isin(["USA", "CHN", "RUS", "NLD"])].sort_values(["iso3", "port_rank"]))
# Out:
# Wake Island not found in regex
# Johnson Atoll not found in regex
# Midway Islands not found in regex
#  not found in regex
#  not found in regex
#  not found in regex
#  not found in regex
#      iso3                    port_name   latitude  longitude  \
# 563   ABW           Sint Nicolaas Baai  12.433333 -69.916667
# 3146  ABW  Paarden Baai - (Oranjestad)  12.516667 -70.033333
# 512   AGO                      Cabinda  -5.533333  12.200000
# 1783  AGO            Estrela Oil Field  -6.450000  12.400000
# 281   AGO                       Lobito -12.333333  13.566667
# 2523  AGO                       Luanda  -8.800000  13.250000
# 1331  AGO         Malongo Oil Terminal  -5.433333  12.083333
# 1416  ALB                       Durres  41.316667  19.450000
# 2726  ALB                     Shengjin  41.816667  19.600000
# 2638  ALB                       Vlores  40.466667  19.500000
# 546   ARE               Mina Jabal Ali  25.016667  55.050000
# 3033  ARE                  Al Fujayrah  25.173056  56.369167
# 2457  ARE                 Khawr Fakkan  25.362778  56.368889
# 1887  ARE                     Abu Zaby  24.500000  54.333333
# 2242  ARE       Jabal Az Zannah/ruways  24.200000  52.700000
# 515   ARG                 Buenos Aires -34.600000 -58.366667
# 514   ARG                     La Plata -34.833333 -57.883333
# 1953  ARG                      Rosario -32.950000 -60.633333
# 2022  ARG                      Campana -34.150000 -58.966667
# 1540  ARG       Concepcion Del Uruguay -32.483333 -58.233333
#
#                                        world_water_body      port_basin  \
# 563                 Caribbean Sea; North Atlantic Ocean       CARIBBEAN
# 3146                Caribbean Sea; North Atlantic Ocean       CARIBBEAN
# 512                                South Atlantic Ocean  SOUTH_ATLANTIC
# 1783                               South Atlantic Ocean  SOUTH_ATLANTIC
# 281                                South Atlantic Ocean  SOUTH_ATLANTIC
# 2523                               South Atlantic Ocean  SOUTH_ATLANTIC
# 1331                               South Atlantic Ocean  SOUTH_ATLANTIC
# 1416  Adriatic Sea; Mediterranean Sea; North Atlanti...   MEDITERRANEAN
# 2726  Adriatic Sea; Mediterranean Sea; North Atlanti...   MEDITERRANEAN
# 2638  Adriatic Sea; Mediterranean Sea; North Atlanti...   MEDITERRANEAN
# 546                          Persian Gulf; Indian Ocean            GULF
# 3033                         Gulf of Oman; Indian Ocean    INDIAN_OCEAN
# 2457                         Gulf of Oman; Indian Ocean    INDIAN_OCEAN
# 1887                         Persian Gulf; Indian Ocean            GULF
# 2242                         Persian Gulf; Indian Ocean            GULF
# 515               Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
# 514               Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
# 1953              Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
# 2022              Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
# 1540              Rio de la Plata; South Atlantic Ocean  SOUTH_ATLANTIC
#
#      harbor_size           harbor_type harbor_use  fac_container  \
# 563        Small  Coastal (Breakwater)    Unknown              0
# 3146  Very Small  Coastal (Breakwater)    Unknown              0
# 512        Small        Open Roadstead    Unknown              0
# 1783       Small        Open Roadstead    Unknown              0
# 281        Small     Coastal (Natural)    Unknown              0
# 2523       Small     Coastal (Natural)    Unknown              0
# 1331       Small        Open Roadstead    Unknown              0
# 1416       Small  Coastal (Breakwater)    Unknown              0
# 2726  Very Small     Coastal (Natural)    Unknown              0
# 2638  Very Small     Coastal (Natural)    Unknown              0
# 546        Large  Coastal (Breakwater)    Unknown              0
# 3033       Small  Coastal (Breakwater)      Cargo              1
# 2457      Medium     Coastal (Natural)    Unknown              1
# 1887      Medium  Coastal (Breakwater)    Unknown              0
# 2242      Medium  Coastal (Breakwater)    Unknown              0
# 515        Large  Coastal (Breakwater)    Unknown              0
# 514       Medium        River (Basins)    Unknown              0
# 1953      Medium       River (Natural)    Unknown              0
# 2022       Small       River (Natural)    Unknown              0
# 1540       Small       River (Natural)    Unknown              0
#
#       fac_solid_bulk  fac_liquid_bulk  fac_oil_terminal  fac_lng_terminal  \
# 563                0                0                 0                 0
# 3146               0                0                 0                 0
# 512                0                0                 0                 0
# 1783               0                0                 0                 0
# 281                0                0                 0                 0
# 2523               0                0                 0                 0
# 1331               0                0                 0                 0
# 1416               0                0                 0                 0
# 2726               0                0                 0                 0
# 2638               0                0                 0                 0
# 546                0                0                 0                 0
# 3033               1                1                 1                 0
# 2457               0                0                 0                 0
# 1887               0                0                 0                 0
# 2242               0                0                 0                 0
# 515                0                0                 0                 0
# 514                0                0                 0                 0
# 1953               0                0                 0                 0
# 2022               0                0                 0                 0
# 1540               0                0                 0                 0
#
#       port_score  port_rank
# 563           20          1
# 3146          10          2
# 512           20          1
# 1783          20          2
# 281           20          3
# 2523          20          4
# 1331          20          5
# 1416          20          1
# 2726          10          2
# 2638          10          3
# 546           40          1
# 3033          39          2
# 2457          35          3
# 1887          30          4
# 2242          30          5
# 515           40          1
# 514           30          2
# 1953          30          3
# 2022          20          4
# 1540          20          5
#      iso3                    port_name   latitude   longitude  \
# 271   CHN                       Dalian  38.916667  121.666667
# 1807  CHN            Lon Shui Terminal  20.833333  115.683333
# 674   CHN                 Qingdao Gang  36.033333  120.266667
# 2829  CHN                     Shanghai  31.216667  121.500000
# 2846  CHN             Tianjin Xin Gang  38.966667  117.833333
# 2506  CHN                       Xiamen  24.450000  118.066667
# 679   CHN                     Quanzhou  24.883333  118.600000
# 1451  NLD                    Amsterdam  52.366667    4.900000
# 2599  NLD                    Rotterdam  51.900000    4.483333
# 914   NLD                    Dordrecht  51.816667    4.650000
# 1596  NLD                    Europoort  51.950000    4.116667
# 2721  NLD                    Terneuzen  51.350000    3.816667
# 2454  RUS                  Vladivostok  43.108889  131.888333
# 2538  RUS                  Kaliningrad  54.700000   20.483333
# 3613  RUS                       Vyborg  60.716667   28.750000
# 1354  RUS                     Murmansk  68.983333   33.050000
# 909   RUS                 Novorossiysk  44.716667   37.783333
# 3248  RUS                 Arkhangels'k  64.529722   40.521667
# 2470  RUS                    De Kastri  51.466667  140.783333
# 980   RUS  Aleksandrovsk -Sakhalinskiy  50.900000  142.133333
# 2495  RUS                     Nakhodka  42.800000  132.883333
# 985   RUS               Rostov-Na-Donu  47.166667   39.716667
# 1046  USA                    Baltimore  39.266667  -76.583333
# 1459  USA                       Boston  42.350000  -71.050000
# 1352  USA                     Brooklyn  40.666667  -74.016667
# 237   USA                      Buffalo  42.883333  -78.883333
# 1048  USA                      Chester  39.850000  -75.350000
# 2452  USA                    Cleveland  41.500000  -81.716667
# 468   USA                  Los Angeles  33.750000 -118.250000
# 1205  USA                      Oakland  37.816667 -122.333333
# 2307  USA                       Barrow  71.283333 -156.783333
# 1592  USA               Bernard Harbor  70.133333 -143.633333
#
#                                        world_water_body  \
# 271                     Yellow Sea; North Pacific Ocean
# 1807               South China Sea; North Pacific Ocean
# 674                     Yellow Sea; North Pacific Ocean
# 2829                East China Sea; North Pacific Ocean
# 2846            Bo Hai; Yellow Sea; North Pacific Ocean
# 2506                 Taiwan Strait; North Pacific Ocean
# 679                  Taiwan Strait; North Pacific Ocean
# 1451                    North Sea; North Atlantic Ocean
# 2599                    North Sea; North Atlantic Ocean
# 914                     North Sea; North Atlantic Ocean
# 1596                    North Sea; North Atlantic Ocean
# 2721                    North Sea; North Atlantic Ocean
# 2454                  Sea of Japan; North Pacific Ocean
# 2538                   Baltic Sea; North Atlantic Ocean
# 3613  Gulf of Finland; Baltic Sea; North Atlantic Ocean
# 1354                          Barents Sea; Arctic Ocean
# 909                     Black Sea; North Atlantic Ocean
# 3248               White Sea; Barents Sea; Arctic Ocean
# 2470                  Tatar Strait; North Pacific Ocean
# 980                   Tatar Strait; North Pacific Ocean
# 2495                  Sea of Japan; North Pacific Ocean
# 985        Sea of Azov; Black Sea; North Atlantic Ocean
# 1046                               North Atlantic Ocean
# 1459                               North Atlantic Ocean
# 1352                               North Atlantic Ocean
# 237                              Lake Erie; Great Lakes
# 1048                               North Atlantic Ocean
# 2452                             Lake Erie; Great Lakes
# 468                                 North Pacific Ocean
# 1205                                North Pacific Ocean
# 2307                                       Arctic Ocean
# 1592                         Beaufort Sea; Arctic Ocean
#
#                   port_basin harbor_size           harbor_type harbor_use  \
# 271          WESTERN_PACIFIC       Large  Coastal (Breakwater)    Unknown
# 1807         WESTERN_PACIFIC       Large        Open Roadstead    Unknown
# 674          WESTERN_PACIFIC       Large        Open Roadstead    Unknown
# 2829         WESTERN_PACIFIC       Large       River (Natural)    Unknown
# 2846         WESTERN_PACIFIC       Large       River (Natural)    Unknown
# 2506                 PACIFIC      Medium       River (Natural)    Unknown
# 679                  PACIFIC       Small     Coastal (Natural)    Unknown
# 1451   NORTH_ATLANTIC_EUROPE       Large         Canal or Lake    Unknown
# 2599   NORTH_ATLANTIC_EUROPE       Large        River (Basins)    Unknown
# 914    NORTH_ATLANTIC_EUROPE      Medium       River (Natural)    Unknown
# 1596   NORTH_ATLANTIC_EUROPE      Medium         Canal or Lake    Unknown
# 2721   NORTH_ATLANTIC_EUROPE      Medium    River (Tide Gates)    Unknown
# 2454         WESTERN_PACIFIC       Large     Coastal (Natural)      Cargo
# 2538                  BALTIC      Medium        River (Basins)    Unknown
# 3613                  BALTIC      Medium     Coastal (Natural)    Unknown
# 1354         UNKNOWN_COASTAL       Large       River (Natural)    Unknown
# 909                BLACK_SEA       Large  Coastal (Breakwater)    Unknown
# 3248         UNKNOWN_COASTAL      Medium       River (Natural)    Unknown
# 2470                 PACIFIC      Medium     Coastal (Natural)    Unknown
# 980                  PACIFIC       Small        Open Roadstead    Unknown
# 2495         WESTERN_PACIFIC       Small     Coastal (Natural)    Unknown
# 985                BLACK_SEA       Small        River (Basins)    Unknown
# 1046  NORTH_AMERICA_ATLANTIC       Large       River (Natural)    Unknown
# 1459  NORTH_AMERICA_ATLANTIC       Large     Coastal (Natural)    Unknown
# 1352  NORTH_AMERICA_ATLANTIC       Large       River (Natural)    Unknown
# 237          INLAND_WATERWAY       Large  Coastal (Breakwater)    Unknown
# 1048  NORTH_AMERICA_ATLANTIC       Large       River (Natural)    Unknown
# 2452         INLAND_WATERWAY       Large  Coastal (Breakwater)    Unknown
# 468                  PACIFIC       Large  Coastal (Breakwater)    Unknown
# 1205                 PACIFIC       Large     Coastal (Natural)    Unknown
# 2307         UNKNOWN_COASTAL  Very Small        Open Roadstead    Unknown
# 1592         UNKNOWN_COASTAL  Very Small        Open Roadstead    Unknown
#
#       fac_container  fac_solid_bulk  fac_liquid_bulk  fac_oil_terminal  \
# 271               0               0                0                 0
# 1807              0               0                0                 0
# 674               0               0                0                 0
# 2829              0               0                0                 0
# 2846              0               0                0                 0
# 2506              0               0                0                 0
# 679               0               0                0                 0
# 1451              0               0                0                 0
# 2599              0               0                0                 0
# 914               0               0                0                 0
# 1596              0               0                0                 0
# 2721              0               0                0                 0
# 2454              1               1                1                 1
# 2538              1               1                1                 0
# 3613              1               1                1                 0
# 1354              0               0                0                 0
# 909               0               0                0                 0
# 3248              0               0                0                 0
# 2470              0               0                0                 0
# 980               0               0                0                 0
# 2495              0               0                0                 0
# 985               0               0                0                 0
# 1046              0               0                0                 0
# 1459              0               0                0                 0
# 1352              0               0                0                 0
# 237               0               0                0                 0
# 1048              0               0                0                 0
# 2452              0               0                0                 0
# 468               0               0                0                 0
# 1205              0               0                0                 0
# 2307              0               0                0                 0
# 1592              0               0                0                 0
#
#       fac_lng_terminal  port_score  port_rank
# 271                  0          40          1
# 1807                 0          40          2
# 674                  0          40          3
# 2829                 0          40          4
# 2846                 0          40          5
# 2506                 0          30          6
# 679                  0          20          7
# 1451                 0          40          1
# 2599                 0          40          2
# 914                  0          30          3
# 1596                 0          30          4
# 2721                 0          30          5
# 2454                 0          59          1
# 2538                 0          43          2
# 3613                 0          43          3
# 1354                 0          40          4
# 909                  0          40          5
# 3248                 0          30          6
# 2470                 0          30          7
# 980                  0          20          8
# 2495                 0          20          9
# 985                  0          20         10
# 1046                 0          40          1
# 1459                 0          40          2
# 1352                 0          40          3
# 237                  0          40          4
# 1048                 0          40          5
# 2452                 0          40          6
# 468                  0          40          7
# 1205                 0          40          8
# 2307                 0          10          9
# 1592                 0          10         10

# %%
# coverage check for ports, landlocked handling, and dynamic gateway logic
country_port_coverage = (
    dim_country_ports.groupby("iso3", as_index=False)["port_rank"]
    .count()
    .rename(columns={"port_rank": "ports_found"})
)

# Added 'is_eu' to leverage your dimensional tagging
country_geo = dim_country[["iso3", "country_name", "continent", "region", "subregion", "is_eu"]].drop_duplicates().copy()
country_geo = country_geo.merge(country_port_coverage[["iso3", "ports_found"]], on="iso3", how="left")

# Safely handle numeric and boolean NAs to avoid evaluation errors
country_geo["ports_found"] = country_geo["ports_found"].fillna(0).astype(int)
country_geo["has_wpi_ports"] = country_geo["ports_found"] > 0
country_geo["is_eu"] = country_geo["is_eu"].fillna(False).astype(bool)

print("Dynamically computing landlocked gateways via spatial topologies...")

# Load standard low-resolution world map directly from Natural Earth's cloud storage
url = "https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip"
world = gpd.read_file(url)

# Bulletproof column extraction (handles Natural Earth schema drift)
iso_col = 'ADM0_A3' if 'ADM0_A3' in world.columns else 'ISO_A3' if 'ISO_A3' in world.columns else 'ISO_A3_EH'
name_col = 'NAME' if 'NAME' in world.columns else 'ADMIN'

world['iso_a3'] = world[iso_col].astype(str)
world['name'] = world[name_col].astype(str)

# Fix ALL known missing ISO3 codes in Natural Earth (-99 values)
world.loc[world['name'] == 'France', 'iso_a3'] = 'FRA'
world.loc[world['name'] == 'Norway', 'iso_a3'] = 'NOR'
world.loc[world['name'] == 'Somaliland', 'iso_a3'] = 'SOM'
world.loc[world['name'] == 'Kosovo', 'iso_a3'] = 'RKS'
world.loc[world['name'] == 'N. Cyprus', 'iso_a3'] = 'CYP' 

# Merge our port flags into the spatial dataframe
world = world.merge(
    country_geo[['iso3', 'has_wpi_ports']], 
    left_on='iso_a3', right_on='iso3', how='left'
)
# Explicit boolean cast to prevent DataFrame indexing errors
world['has_wpi_ports'] = world['has_wpi_ports'].fillna(False).astype(bool)

LANDLOCKED_GATEWAYS = {}
landlocked_iso3s = country_geo[~country_geo['has_wpi_ports']]['iso3'].tolist()

for iso in landlocked_iso3s:
    # Attempt to find the geometry for the current country
    country_geom_series = world[world['iso_a3'] == iso]['geometry']
    
    # If it's a non-spatial group code (e.g., EUR, F19, S19), geometry will be empty
    if country_geom_series.empty:
        group_info = country_geo[country_geo['iso3'] == iso]
        if not group_info.empty:
            info = group_info.iloc[0]
            
            # Dynamic aggregation based on your dimension tags
            if info['is_eu']:
                gateways = country_geo[(country_geo['is_eu']) & (country_geo['has_wpi_ports'])]['iso3'].tolist()
            elif pd.notna(info['region']) and info['region'] not in ['World', 'Special']:
                gateways = country_geo[(country_geo['region'] == info['region']) & (country_geo['has_wpi_ports'])]['iso3'].tolist()
            elif info['region'] == 'World':
                gateways = ['CHN', 'USA', 'NLD', 'SGP', 'ARE', 'ZAF', 'BRA']
            else:
                gateways = []
                
            if gateways:
                LANDLOCKED_GATEWAYS[iso] = gateways
        continue
        
    geom = country_geom_series.iloc[0]
    
    # 1-Hop: Find direct neighbors (countries whose borders intersect)
    neighbors = world[world.geometry.intersects(geom) & (world['iso_a3'] != iso)]
    coastal_neighbors = neighbors[neighbors['has_wpi_ports']]['iso_a3'].dropna().tolist()
    
    if coastal_neighbors:
        LANDLOCKED_GATEWAYS[iso] = coastal_neighbors
    else:
        # 2-Hop: For doubly-landlocked countries
        if not neighbors.empty:
            hop2_neighbors = world[world.geometry.intersects(neighbors.geometry.unary_union) & (world['iso_a3'] != iso)]
            hop2_coastal = hop2_neighbors[hop2_neighbors['has_wpi_ports']]['iso_a3'].dropna().tolist()
            if hop2_coastal:
                LANDLOCKED_GATEWAYS[iso] = hop2_coastal

# Flag the countries that were dynamically assigned a gateway
country_geo["is_landlocked_assumed"] = country_geo["iso3"].isin(LANDLOCKED_GATEWAYS.keys())
COUNTRY_FLAGS = country_geo.set_index("iso3")[["country_name", "is_landlocked_assumed", "has_wpi_ports", "continent", "region", "subregion"]].to_dict("index")

print(f"Successfully computed coastal gateways for {len(LANDLOCKED_GATEWAYS)} entities.")

display(
    country_geo[
        ["iso3", "country_name", "ports_found", "has_wpi_ports", "is_landlocked_assumed"]
    ].sort_values(["is_landlocked_assumed", "ports_found", "iso3"], ascending=[False, True, True]).head(40)
)
# Out:
# Dynamically computing landlocked gateways via spatial topologies...
# Successfully computed coastal gateways for 57 entities.
# /var/folders/rg/5ylghp0s7jn56p9q3z8vtvt00000gn/T/ipykernel_7839/3843512145.py:83: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   hop2_neighbors = world[world.geometry.intersects(neighbors.geometry.unary_union) & (world['iso_a3'] != iso)]
#     iso3                       country_name  ports_found  has_wpi_ports  \
# 0    A79                          LAIA, nes            0          False
# 2    AFG                        Afghanistan            0          False
# 4    AIA                           Anguilla            0          False
# 6    AND                            Andorra            0          False
# 9    ARM                            Armenia            0          False
# 15   AUT                            Austria            0          False
# 16   AZE                         Azerbaijan            0          False
# 17   BDI                            Burundi            0          False
# 21   BFA                       Burkina Faso            0          False
# 27   BLM                   Saint Barthélemy            0          False
# 28   BLR                            Belarus            0          False
# 31   BOL   Bolivia (Plurinational State of)            0          False
# 35   BTN                             Bhutan            0          False
# 36   BWA                           Botswana            0          False
# 37   CAF               Central African Rep.            0          False
# 39   CCK                         Cocos Isds            0          False
# 40   CHE                        Switzerland            0          False
# 57   CZE                            Czechia            0          False
# 64   E19                  Other Europe, nes            0          False
# 71   ETH                 Ethiopia (...1992)            0          False
# 72   EUR                     European Union            0          False
# 73   F19                  Other Africa, nes            0          False
# 96   HMD  Heard Island and McDonald Islands            0          False
# 100  HUN                            Hungary            0          False
# 113  KAZ                         Kazakhstan            0          False
# 115  KGZ                         Kyrgyzstan            0          False
# 121  LAO             Lao People's Dem. Rep.            0          False
# 127  LSO                            Lesotho            0          False
# 129  LUX                         Luxembourg            0          False
# 133  MDA                    Rep. of Moldova            0          False
# 138  MKD                    North Macedonia            0          False
# 139  MLI                               Mali            0          False
# 143  MNG                           Mongolia            0          False
# 147  MSR                         Montserrat            0          False
# 149  MWI                             Malawi            0          False
# 153  NER                              Niger            0          False
# 159  NPL                              Nepal            0          False
# 165  PCN                           Pitcairn            0          False
# 174  PSE                 State of Palestine            0          False
# 179  RWA                             Rwanda            0          False
#
#      is_landlocked_assumed
# 0                     True
# 2                     True
# 4                     True
# 6                     True
# 9                     True
# 15                    True
# 16                    True
# 17                    True
# 21                    True
# 27                    True
# 28                    True
# 31                    True
# 35                    True
# 36                    True
# 37                    True
# 39                    True
# 40                    True
# 57                    True
# 64                    True
# 71                    True
# 72                    True
# 73                    True
# 96                    True
# 100                   True
# 113                   True
# 115                   True
# 121                   True
# 127                   True
# 129                   True
# 133                   True
# 138                   True
# 139                   True
# 143                   True
# 147                   True
# 149                   True
# 153                   True
# 159                   True
# 165                   True
# 174                   True
# 179                   True

# %%
# persist chokepoint master data and create a scenario-aware basin graph
# REWORKED: graph costs calibrated so Suez is default winner for Med/Europe→East
#   Cape = fallback/disruption only (base_cost 5.5)
#   Panama = Americas Atlantic↔Pacific only (base_cost 6.0)

dim_chokepoint = pd.DataFrame(
    [
        {"chokepoint_name": "Turkish Straits",   "longitude": 29.0,    "latitude": 41.0,    "kind": "strait"},
        {"chokepoint_name": "Suez Canal",         "longitude": 32.5498, "latitude": 30.8167, "kind": "canal"},
        {"chokepoint_name": "Hormuz Strait",      "longitude": 56.25,   "latitude": 26.57,   "kind": "strait"},
        {"chokepoint_name": "Bab el-Mandeb",      "longitude": 43.33,   "latitude": 12.58,   "kind": "strait"},
        {"chokepoint_name": "Panama Canal",       "longitude": -79.58,  "latitude": 9.08,    "kind": "canal"},
        {"chokepoint_name": "Malacca Strait",     "longitude": 99.8,    "latitude": 2.5,     "kind": "strait"},
        {"chokepoint_name": "Gibraltar Strait",   "longitude": -5.6,    "latitude": 35.95,   "kind": "strait"},
        {"chokepoint_name": "Cape of Good Hope",  "longitude": 18.47,   "latitude": -34.36,  "kind": "cape"},
        {"chokepoint_name": "Open Sea",           "longitude": np.nan,  "latitude": np.nan,  "kind": "open_sea"},
    ]
)
dim_chokepoint.to_parquet(CHOKEPOINT_DIM_PATH, index=False)

# Cost design (default_shortest):
#  1.0 = same-ocean connective tissue
#  2.0 = minor regional strait (Turkish, Gibraltar, Bab-Mandeb alone)
#  3.0 = primary trunk chokepoint (Suez, Hormuz, Malacca)
#  5.5 = Cape of Good Hope — deliberately high so Suez always wins Med->IO
#  6.0 = Panama Canal — high so it does NOT win for Med/Europe->Asia
#
# Path cost verification (default_shortest):
#  Med -> Indian Ocean via Suez: Med->RS(3) + RS->IO(2)         = 5.0  <-- wins
#  Med -> Indian Ocean via Cape: Med->ATL(2)+ATL->SAT(1)+SAT->IO(5.5) = 8.5
#  Med -> WPac via Suez+Malacca: Med->RS(3)+RS->IO(2)+IO->WPac(3)    = 8.0  <-- wins
#  Med -> WPac via Panama: Med->ATL(2)+ATL->PAC(6)+PAC->WPac(1)      = 9.0

basin_graph_edges = pd.DataFrame(
    [
        # enclosed / European
        {"origin_basin": "BLACK_SEA",             "destination_basin": "MEDITERRANEAN",          "chokepoint_name": "Turkish Straits",  "base_cost": 2.0},
        {"origin_basin": "MEDITERRANEAN",         "destination_basin": "BLACK_SEA",              "chokepoint_name": "Turkish Straits",  "base_cost": 2.0},
        {"origin_basin": "MEDITERRANEAN",         "destination_basin": "NORTH_ATLANTIC_EUROPE",  "chokepoint_name": "Gibraltar Strait", "base_cost": 2.0},
        {"origin_basin": "NORTH_ATLANTIC_EUROPE", "destination_basin": "MEDITERRANEAN",          "chokepoint_name": "Gibraltar Strait", "base_cost": 2.0},
        {"origin_basin": "MEDITERRANEAN",         "destination_basin": "ATLANTIC",               "chokepoint_name": "Gibraltar Strait", "base_cost": 2.0},
        {"origin_basin": "ATLANTIC",              "destination_basin": "MEDITERRANEAN",          "chokepoint_name": "Gibraltar Strait", "base_cost": 2.0},
        {"origin_basin": "NORTH_ATLANTIC_EUROPE", "destination_basin": "ATLANTIC",               "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "ATLANTIC",              "destination_basin": "NORTH_ATLANTIC_EUROPE",  "chokepoint_name": "Open Sea",         "base_cost": 1.0},

        # Suez corridor (PREFERRED for Europe/Med -> East of Suez)
        {"origin_basin": "MEDITERRANEAN",         "destination_basin": "RED_SEA",                "chokepoint_name": "Suez Canal",       "base_cost": 3.0},
        {"origin_basin": "RED_SEA",               "destination_basin": "MEDITERRANEAN",          "chokepoint_name": "Suez Canal",       "base_cost": 3.0},
        {"origin_basin": "RED_SEA",               "destination_basin": "INDIAN_OCEAN",           "chokepoint_name": "Bab el-Mandeb",    "base_cost": 2.0},
        {"origin_basin": "INDIAN_OCEAN",          "destination_basin": "RED_SEA",                "chokepoint_name": "Bab el-Mandeb",    "base_cost": 2.0},

        # Gulf / Arabian Sea
        {"origin_basin": "ARABIAN_SEA",           "destination_basin": "GULF",                   "chokepoint_name": "Hormuz Strait",    "base_cost": 3.0},
        {"origin_basin": "GULF",                  "destination_basin": "ARABIAN_SEA",             "chokepoint_name": "Hormuz Strait",    "base_cost": 3.0},
        {"origin_basin": "INDIAN_OCEAN",          "destination_basin": "ARABIAN_SEA",             "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "ARABIAN_SEA",           "destination_basin": "INDIAN_OCEAN",           "chokepoint_name": "Open Sea",         "base_cost": 1.0},

        # Asia corridor (Malacca)
        {"origin_basin": "INDIAN_OCEAN",          "destination_basin": "WESTERN_PACIFIC",         "chokepoint_name": "Malacca Strait",   "base_cost": 3.0},
        {"origin_basin": "WESTERN_PACIFIC",       "destination_basin": "INDIAN_OCEAN",           "chokepoint_name": "Malacca Strait",   "base_cost": 3.0},

        # Atlantic / Pacific (Panama) — high cost; Americas logic only
        {"origin_basin": "ATLANTIC",              "destination_basin": "PACIFIC",                 "chokepoint_name": "Panama Canal",     "base_cost": 8.0},
        {"origin_basin": "PACIFIC",               "destination_basin": "ATLANTIC",               "chokepoint_name": "Panama Canal",     "base_cost": 8.0},
        {"origin_basin": "NORTH_AMERICA_ATLANTIC","destination_basin": "PACIFIC",                "chokepoint_name": "Panama Canal",     "base_cost": 8.0},
        {"origin_basin": "PACIFIC",               "destination_basin": "NORTH_AMERICA_ATLANTIC", "chokepoint_name": "Panama Canal",     "base_cost": 8.0},
        {"origin_basin": "NORTH_AMERICA_ATLANTIC","destination_basin": "ATLANTIC",               "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "ATLANTIC",              "destination_basin": "NORTH_AMERICA_ATLANTIC",  "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "CARIBBEAN",             "destination_basin": "ATLANTIC",               "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "ATLANTIC",              "destination_basin": "CARIBBEAN",              "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "CARIBBEAN",             "destination_basin": "PACIFIC",                "chokepoint_name": "Panama Canal",     "base_cost": 8.0},
        {"origin_basin": "PACIFIC",               "destination_basin": "CARIBBEAN",              "chokepoint_name": "Panama Canal",     "base_cost": 8.0},

        # Cape of Good Hope (FALLBACK only — very expensive under default)
        {"origin_basin": "INDIAN_OCEAN",          "destination_basin": "SOUTH_ATLANTIC",          "chokepoint_name": "Cape of Good Hope","base_cost": 7.0},
        {"origin_basin": "SOUTH_ATLANTIC",        "destination_basin": "INDIAN_OCEAN",            "chokepoint_name": "Cape of Good Hope","base_cost": 7.0   },
        {"origin_basin": "SOUTH_ATLANTIC",        "destination_basin": "ATLANTIC",               "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "ATLANTIC",              "destination_basin": "SOUTH_ATLANTIC",         "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "WEST_AFRICA_ATLANTIC",  "destination_basin": "ATLANTIC",               "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "ATLANTIC",              "destination_basin": "WEST_AFRICA_ATLANTIC",   "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "EAST_AFRICA_INDIAN",   "destination_basin": "INDIAN_OCEAN",            "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "INDIAN_OCEAN",          "destination_basin": "EAST_AFRICA_INDIAN",     "chokepoint_name": "Open Sea",         "base_cost": 1.0},

        # same-ocean connective tissue
        {"origin_basin": "WESTERN_PACIFIC",       "destination_basin": "PACIFIC",                "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "PACIFIC",               "destination_basin": "WESTERN_PACIFIC",        "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "SOUTH_AMERICA_PACIFIC", "destination_basin": "PACIFIC",               "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "PACIFIC",               "destination_basin": "SOUTH_AMERICA_PACIFIC",  "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "BALTIC",                "destination_basin": "NORTH_ATLANTIC_EUROPE",  "chokepoint_name": "Open Sea",         "base_cost": 1.0},
        {"origin_basin": "NORTH_ATLANTIC_EUROPE", "destination_basin": "BALTIC",                 "chokepoint_name": "Open Sea",         "base_cost": 1.0},
    ]
)


def apply_scenario_weights(edges: pd.DataFrame, route_scenario: str) -> pd.DataFrame:
    edges = edges.copy()
    edges["scenario_cost"] = edges["base_cost"]

    if route_scenario == "suez_disrupted":
        # Suez/BaM closed -> Cape becomes viable; Panama cheaper for Americas
        edges.loc[edges["chokepoint_name"].isin(["Suez Canal", "Bab el-Mandeb"]), "scenario_cost"] += 9.0
        edges.loc[edges["chokepoint_name"].eq("Cape of Good Hope"), "scenario_cost"] -= 2.0

    elif route_scenario == "panama_disrupted":
        edges.loc[edges["chokepoint_name"].eq("Panama Canal"), "scenario_cost"] += 9.0

    elif route_scenario == "cape_preferred":
        edges.loc[edges["chokepoint_name"].isin(["Suez Canal", "Bab el-Mandeb"]), "scenario_cost"] += 4.0
        edges.loc[edges["chokepoint_name"].eq("Cape of Good Hope"), "scenario_cost"] -= 2.5

    elif route_scenario == "risk_avoidance":
        edges.loc[edges["chokepoint_name"].isin(["Hormuz Strait", "Bab el-Mandeb", "Suez Canal"]), "scenario_cost"] += 5.0

    return edges


basin_graph_edges = apply_scenario_weights(basin_graph_edges, ROUTE_SCENARIO)
basin_graph_edges.to_parquet(BASIN_EDGE_PATH, index=False)

display(basin_graph_edges)
# Out:
#               origin_basin       destination_basin    chokepoint_name  \
# 0                BLACK_SEA           MEDITERRANEAN    Turkish Straits
# 1            MEDITERRANEAN               BLACK_SEA    Turkish Straits
# 2            MEDITERRANEAN   NORTH_ATLANTIC_EUROPE   Gibraltar Strait
# 3    NORTH_ATLANTIC_EUROPE           MEDITERRANEAN   Gibraltar Strait
# 4            MEDITERRANEAN                ATLANTIC   Gibraltar Strait
# 5                 ATLANTIC           MEDITERRANEAN   Gibraltar Strait
# 6    NORTH_ATLANTIC_EUROPE                ATLANTIC           Open Sea
# 7                 ATLANTIC   NORTH_ATLANTIC_EUROPE           Open Sea
# 8            MEDITERRANEAN                 RED_SEA         Suez Canal
# 9                  RED_SEA           MEDITERRANEAN         Suez Canal
# 10                 RED_SEA            INDIAN_OCEAN      Bab el-Mandeb
# 11            INDIAN_OCEAN                 RED_SEA      Bab el-Mandeb
# 12             ARABIAN_SEA                    GULF      Hormuz Strait
# 13                    GULF             ARABIAN_SEA      Hormuz Strait
# 14            INDIAN_OCEAN             ARABIAN_SEA           Open Sea
# 15             ARABIAN_SEA            INDIAN_OCEAN           Open Sea
# 16            INDIAN_OCEAN         WESTERN_PACIFIC     Malacca Strait
# 17         WESTERN_PACIFIC            INDIAN_OCEAN     Malacca Strait
# 18                ATLANTIC                 PACIFIC       Panama Canal
# 19                 PACIFIC                ATLANTIC       Panama Canal
# 20  NORTH_AMERICA_ATLANTIC                 PACIFIC       Panama Canal
# 21                 PACIFIC  NORTH_AMERICA_ATLANTIC       Panama Canal
# 22  NORTH_AMERICA_ATLANTIC                ATLANTIC           Open Sea
# 23                ATLANTIC  NORTH_AMERICA_ATLANTIC           Open Sea
# 24               CARIBBEAN                ATLANTIC           Open Sea
# 25                ATLANTIC               CARIBBEAN           Open Sea
# 26               CARIBBEAN                 PACIFIC       Panama Canal
# 27                 PACIFIC               CARIBBEAN       Panama Canal
# 28            INDIAN_OCEAN          SOUTH_ATLANTIC  Cape of Good Hope
# 29          SOUTH_ATLANTIC            INDIAN_OCEAN  Cape of Good Hope
# 30          SOUTH_ATLANTIC                ATLANTIC           Open Sea
# 31                ATLANTIC          SOUTH_ATLANTIC           Open Sea
# 32    WEST_AFRICA_ATLANTIC                ATLANTIC           Open Sea
# 33                ATLANTIC    WEST_AFRICA_ATLANTIC           Open Sea
# 34      EAST_AFRICA_INDIAN            INDIAN_OCEAN           Open Sea
# 35            INDIAN_OCEAN      EAST_AFRICA_INDIAN           Open Sea
# 36         WESTERN_PACIFIC                 PACIFIC           Open Sea
# 37                 PACIFIC         WESTERN_PACIFIC           Open Sea
# 38   SOUTH_AMERICA_PACIFIC                 PACIFIC           Open Sea
# 39                 PACIFIC   SOUTH_AMERICA_PACIFIC           Open Sea
# 40                  BALTIC   NORTH_ATLANTIC_EUROPE           Open Sea
# 41   NORTH_ATLANTIC_EUROPE                  BALTIC           Open Sea
#
#     base_cost  scenario_cost
# 0         2.0            2.0
# 1         2.0            2.0
# 2         2.0            2.0
# 3         2.0            2.0
# 4         2.0            2.0
# 5         2.0            2.0
# 6         1.0            1.0
# 7         1.0            1.0
# 8         3.0            3.0
# 9         3.0            3.0
# 10        2.0            2.0
# 11        2.0            2.0
# 12        3.0            3.0
# 13        3.0            3.0
# 14        1.0            1.0
# 15        1.0            1.0
# 16        3.0            3.0
# 17        3.0            3.0
# 18        8.0            8.0
# 19        8.0            8.0
# 20        8.0            8.0
# 21        8.0            8.0
# 22        1.0            1.0
# 23        1.0            1.0
# 24        1.0            1.0
# 25        1.0            1.0
# 26        8.0            8.0
# 27        8.0            8.0
# 28        7.0            7.0
# 29        7.0            7.0
# 30        1.0            1.0
# 31        1.0            1.0
# 32        1.0            1.0
# 33        1.0            1.0
# 34        1.0            1.0
# 35        1.0            1.0
# 36        1.0            1.0
# 37        1.0            1.0
# 38        1.0            1.0
# 39        1.0            1.0
# 40        1.0            1.0
# 41        1.0            1.0

# %%
# optional transshipment hub support
dim_transshipment_hub = pd.DataFrame(
    [
        {"hub_port": "Rotterdam", "hub_iso3": "NLD", "hub_basin": "NORTH_ATLANTIC_EUROPE", "hub_rank": 1},
        {"hub_port": "Piraeus", "hub_iso3": "GRC", "hub_basin": "MEDITERRANEAN", "hub_rank": 1},
        {"hub_port": "Algeciras", "hub_iso3": "ESP", "hub_basin": "MEDITERRANEAN", "hub_rank": 2},
        {"hub_port": "Valencia", "hub_iso3": "ESP", "hub_basin": "MEDITERRANEAN", "hub_rank": 3},
        {"hub_port": "Singapore", "hub_iso3": "SGP", "hub_basin": "WESTERN_PACIFIC", "hub_rank": 1},
        {"hub_port": "Jebel Ali", "hub_iso3": "ARE", "hub_basin": "GULF", "hub_rank": 1},
    ]
)

bridge_basin_default_hubs = pd.DataFrame(
    [
        {"origin_basin": "BLACK_SEA", "destination_basin": "ATLANTIC", "hub_basin": "MEDITERRANEAN", "hub_rank": 1},
        {"origin_basin": "BLACK_SEA", "destination_basin": "NORTH_AMERICA_ATLANTIC", "hub_basin": "MEDITERRANEAN", "hub_rank": 1},
        {"origin_basin": "BLACK_SEA", "destination_basin": "WESTERN_PACIFIC", "hub_basin": "MEDITERRANEAN", "hub_rank": 1},
        {"origin_basin": "WEST_AFRICA_ATLANTIC", "destination_basin": "WESTERN_PACIFIC", "hub_basin": "ATLANTIC", "hub_rank": 1},
        {"origin_basin": "MEDITERRANEAN", "destination_basin": "WESTERN_PACIFIC", "hub_basin": "MEDITERRANEAN", "hub_rank": 1},
    ]
)

dim_transshipment_hub.to_parquet(TRANSHIPMENT_HUB_PATH, index=False)
bridge_basin_default_hubs.to_parquet(BASIN_HUB_BRIDGE_PATH, index=False)

display(dim_transshipment_hub)
display(bridge_basin_default_hubs)
# Out:
#     hub_port hub_iso3              hub_basin  hub_rank
# 0  Rotterdam      NLD  NORTH_ATLANTIC_EUROPE         1
# 1    Piraeus      GRC          MEDITERRANEAN         1
# 2  Algeciras      ESP          MEDITERRANEAN         2
# 3   Valencia      ESP          MEDITERRANEAN         3
# 4  Singapore      SGP        WESTERN_PACIFIC         1
# 5  Jebel Ali      ARE                   GULF         1
#            origin_basin       destination_basin      hub_basin  hub_rank
# 0             BLACK_SEA                ATLANTIC  MEDITERRANEAN         1
# 1             BLACK_SEA  NORTH_AMERICA_ATLANTIC  MEDITERRANEAN         1
# 2             BLACK_SEA         WESTERN_PACIFIC  MEDITERRANEAN         1
# 3  WEST_AFRICA_ATLANTIC         WESTERN_PACIFIC       ATLANTIC         1
# 4         MEDITERRANEAN         WESTERN_PACIFIC  MEDITERRANEAN         1

# %%
# build route candidates robustly across schema variations
work_df = silver_df.copy()

# Ensure optional grouping field exists.
if "partner2_iso3" not in work_df.columns:
    if "partner2Code" in work_df.columns and "code_to_iso3" in globals():
        work_df["partner2_iso3"] = work_df["partner2Code"].map(code_to_iso3)
    else:
        work_df["partner2_iso3"] = pd.NA

# Guard numeric field used in aggregation.
if "trade_value_usd" not in work_df.columns:
    work_df["trade_value_usd"] = 0.0

# Normalize MOT values once so set-membership checks are stable across int/float/string input.
work_df["mot_code_norm"] = pd.to_numeric(work_df.get("motCode"), errors="coerce")

def _mot_set(series):
    vals = pd.to_numeric(series, errors="coerce").dropna().astype(int).unique().tolist()
    return set(vals)

def _codes_seen(series):
    vals = sorted(_mot_set(series))
    return "|".join(str(v) for v in vals)

route_candidates = (
    work_df
    .dropna(subset=["reporter_iso3", "partner_iso3"])
    .groupby(["reporter_iso3", "partner_iso3", "partner2_iso3"], dropna=False)
    .agg(
        row_count=("partner_iso3", "size"),
        trade_value_usd=("trade_value_usd", "sum"),
        has_sea=("mot_code_norm", lambda s: bool(_mot_set(s) & SEA_CODES)),
        has_inland_water=("mot_code_norm", lambda s: bool(_mot_set(s) & INLAND_WATER_CODES)),
        has_unknown=("mot_code_norm", lambda s: bool(_mot_set(s) & UNKNOWN_CODES)),
        has_non_marine=("mot_code_norm", lambda s: bool(_mot_set(s) & NON_MARINE_CODES)),
        mot_codes_seen=("mot_code_norm", _codes_seen),
    )
    .reset_index()
 )

route_candidates["transport_evidence"] = np.select(
    [
        route_candidates["has_sea"],
        route_candidates["has_inland_water"],
        route_candidates["has_unknown"] & ~route_candidates[["has_sea", "has_inland_water", "has_non_marine"]].any(axis=1),
        route_candidates["has_non_marine"] & ~route_candidates[["has_sea", "has_inland_water"]].any(axis=1),
    ],
    [
        "sea_observed",
        "inland_water_only",
        "transport_unknown",
        "non_maritime_only",
    ],
    default="unclassified",
)

# extract maritime-eligible route keys for a clean rebuild of the dimension
existing_keys = set()
if (not FULL_REBUILD_DIM_TRADE_ROUTES) and (not dim_trade_routes_existing.empty):
    existing_keys = set(
        dim_trade_routes_existing[["reporter_iso3", "partner_iso3", "partner2_iso3"]]
        .fillna("__NULL__")
        .itertuples(index=False, name=None)
    )

display(
    route_candidates["transport_evidence"]
    .value_counts(dropna=False)
    .rename_axis("transport_evidence")
    .reset_index(name="route_count")
)

display(route_candidates.head(10))
print("Route candidate keys prepared:", len(route_candidates))
# Out:
#   transport_evidence  route_count
# 0  transport_unknown         1379
# 1       sea_observed         1373
# 2  non_maritime_only          138
# 3  inland_water_only            7
#   reporter_iso3 partner_iso3  partner2_iso3  row_count  trade_value_usd  \
# 0           BGR          AGO            NaN         16     1.117763e+06
# 1           BGR          ALB            NaN        528     6.187100e+08
# 2           BGR          ARE            NaN        250     1.508292e+08
# 3           BGR          ARG            NaN        341     1.413164e+07
# 4           BGR          ARM            NaN        238     1.966293e+07
# 5           BGR          ATG            NaN         24     5.069904e+05
# 6           BGR          AUS            NaN        106     3.912566e+06
# 7           BGR          AUT            NaN       1890     3.797258e+08
# 8           BGR          AZE            NaN        250     6.370388e+08
# 9           BGR          BEL            NaN       1394     6.942962e+08
#
#    has_sea  has_inland_water  has_unknown  has_non_marine  \
# 0     True             False         True            True
# 1     True             False         True            True
# 2     True              True         True            True
# 3     True             False         True            True
# 4     True             False         True            True
# 5     True             False         True            True
# 6     True             False         True            True
# 7    False              True         True            True
# 8     True             False         True            True
# 9     True             False         True            True
#
#                mot_codes_seen transport_evidence
# 0                 0|1000|2100       sea_observed
# 1            0|1000|2100|3200       sea_observed
# 2       0|1000|2100|2200|3200       sea_observed
# 3       0|1000|2100|3100|3200       sea_observed
# 4                 0|2100|3200       sea_observed
# 5                 0|2100|3200       sea_observed
# 6            0|1000|2100|3200       sea_observed
# 7  0|1000|2200|3100|3200|9200  inland_water_only
# 8       0|1000|2100|3100|3200       sea_observed
# 9  0|1000|2100|3100|3200|9200       sea_observed
# Route candidate keys prepared: 2897

# %%
# build dim_trade_routes — corridor-aware port selection, split chokepoint fields,
# aggressive confidence scoring
# CHANGES vs previous version:
#  1. choose_best_port_pair: corridor-aware port ordering for multi-basin countries
#  2. _corridor_penalty: penalises Cape/Panama wins on Suez-natural routes
#  3. Chokepoint schema: first_chokepoint, last_chokepoint, chokepoint_sequence, headline_exposure_group
#  4. _assign_confidence: more aggressive downgrade to low/very_low
#  5. Routing decision layer added:
#       - transport_evidence = what Comtrade MOT suggests
#       - routing_decision   = whether the model should route
#       - direct land-border filter for unknown transport pairs

country_ports_clean = (
    dim_country_ports
    .dropna(subset=["iso3", "port_name", "latitude", "longitude"])
    .copy()
)

COUNTRY_PORTS = (
    country_ports_clean.sort_values(["iso3", "port_rank", "port_name"])
    .groupby("iso3")
    .apply(
        lambda g: [
            {
                "port_name": row.port_name,
                "lonlat": (float(row.longitude), float(row.latitude)),
                "port_basin": row.port_basin,
                "port_score": float(row.port_score) if pd.notna(row.port_score) else 0.0,
                "world_water_body": row.world_water_body,
                "fac_container": int(row.fac_container) if pd.notna(row.fac_container) else 0,
                "fac_solid_bulk": int(row.fac_solid_bulk) if pd.notna(row.fac_solid_bulk) else 0,
                "fac_liquid_bulk": int(row.fac_liquid_bulk) if pd.notna(row.fac_liquid_bulk) else 0,
                "fac_oil_terminal": int(row.fac_oil_terminal) if pd.notna(row.fac_oil_terminal) else 0,
                "fac_lng_terminal": int(row.fac_lng_terminal) if pd.notna(row.fac_lng_terminal) else 0,
            }
            for row in g.itertuples(index=False)
        ]
    )
    .to_dict()
)

# ---------------------------------------------------------------------------
# Routing decision helpers
# ---------------------------------------------------------------------------

DIRECT_LAND_BORDER_PAIRS = {
    "FRA": {"ESP", "DEU", "BEL", "LUX", "ITA", "CHE"},
    "DEU": {"FRA", "BEL", "NLD", "LUX", "CHE", "AUT", "CZE", "POL", "DNK"},
    "ESP": {"FRA", "PRT"},
    "USA": {"CAN", "MEX"},
    "CHN": {
        "RUS", "MNG", "PRK", "VNM", "LAO", "MMR", "IND", "BTN", "NPL",
        "PAK", "AFG", "TJK", "KGZ", "KAZ"
    },
    "NLD": {"BEL", "DEU"},
    "BEL": {"FRA", "DEU", "NLD", "LUX"},
    "ROU": {"BGR", "HUN", "SRB", "UKR", "MDA"},
    "BGR": {"ROU", "SRB", "MKD", "GRC", "TUR"},
}

def has_candidate_ports(iso3: str) -> bool:
    return bool(COUNTRY_PORTS.get(iso3))

def shares_direct_land_border(reporter_iso3: str, partner_iso3: str) -> bool:
    return partner_iso3 in DIRECT_LAND_BORDER_PAIRS.get(reporter_iso3, set())

def should_route_unknown_transport_by_sea(row) -> bool:
    """
    Route unknown transport pairs only when:
    - transport evidence is unknown
    - both countries have candidate ports
    - the pair is not an obvious direct land-border pair
    """
    if row.transport_evidence != "transport_unknown":
        return False

    reporter_iso3 = row.reporter_iso3
    partner_iso3 = row.partner_iso3

    if not has_candidate_ports(reporter_iso3):
        return False

    if not has_candidate_ports(partner_iso3):
        return False

    if shares_direct_land_border(reporter_iso3, partner_iso3):
        return False

    return True

def assign_routing_decision(row) -> str:
    if row.transport_evidence == "sea_observed":
        return "route_by_observed_sea"

    if should_route_unknown_transport_by_sea(row):
        return "route_by_inference"

    return "do_not_route"

HUB_BY_BASIN = (
    dim_transshipment_hub.sort_values(["hub_basin", "hub_rank"])
    .groupby("hub_basin")
    .apply(lambda g: g.iloc[0].to_dict())
    .to_dict()
)

GRAPH = {}
for row in basin_graph_edges.itertuples(index=False):
    GRAPH.setdefault(row.origin_basin, []).append(
        {
            "destination_basin": row.destination_basin,
            "chokepoint_name": row.chokepoint_name,
            "scenario_cost": float(row.scenario_cost),
        }
    )

CHOKEPOINT_COORDS = {
    row["chokepoint_name"]: (row["longitude"], row["latitude"])
    for row in dim_chokepoint.dropna(subset=["longitude", "latitude"]).to_dict("records")
}

# ---------------------------------------------------------------------------
# Corridor-awareness constants
# ---------------------------------------------------------------------------

# Basins for which Suez is the natural exit from Europe/Med
EAST_OF_SUEZ_BASINS = {
    "RED_SEA", "INDIAN_OCEAN", "ARABIAN_SEA", "GULF",
    "EAST_AFRICA_INDIAN", "WESTERN_PACIFIC",
}

# Basins on the Suez-corridor origin side
SUEZ_ORIGIN_BASINS = {
    "MEDITERRANEAN", "NORTH_ATLANTIC_EUROPE", "BALTIC", "BLACK_SEA",
}

def _corridor_penalty(cp_sequence, origin_basin, dest_basin):
    penalty = 0.0
    cp_txt = "|".join(cp_sequence).lower()

    if origin_basin in SUEZ_ORIGIN_BASINS and dest_basin in EAST_OF_SUEZ_BASINS:
        if "panama" in cp_txt:
            penalty += 30.0
        if "cape of good hope" in cp_txt:
            penalty += 18.0

    if origin_basin == "MEDITERRANEAN" and dest_basin == "WESTERN_PACIFIC":
        if "panama" in cp_txt:
            penalty += 40.0

    if origin_basin in {"MEDITERRANEAN", "NORTH_ATLANTIC_EUROPE"} and dest_basin in {"ARABIAN_SEA", "GULF", "INDIAN_OCEAN"}:
        if "cape of good hope" in cp_txt:
            penalty += 22.0

    return penalty

def _gc_distance_km(a_lonlat, b_lonlat):
    lon1, lat1 = map(math.radians, a_lonlat)
    lon2, lat2 = map(math.radians, b_lonlat)
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    h = math.sin(dlat / 2) ** 2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon / 2) ** 2
    return 6371.0088 * (2 * math.asin(math.sqrt(h)))

def _sea_distance_km(a_lonlat, b_lonlat):
    route = sr.searoute(list(a_lonlat), list(b_lonlat), units="km")
    return float(route.properties["length"]), route

def shortest_basin_path(origin_basin, destination_basin):
    if pd.isna(origin_basin) or pd.isna(destination_basin):
        return [], np.inf
    if origin_basin == destination_basin:
        return [], 0.0

    pq = [(0.0, origin_basin, [], set())]
    while pq:
        cost, basin, cp_path, seen = heapq.heappop(pq)
        if basin == destination_basin:
            return cp_path, cost
        if basin in seen:
            continue
        next_seen = set(seen)
        next_seen.add(basin)
        for edge in GRAPH.get(basin, []):
            next_basin = edge["destination_basin"]
            next_cost = cost + edge["scenario_cost"]
            next_path = cp_path + (
                [edge["chokepoint_name"]] if edge["chokepoint_name"] != "Open Sea" else []
            )
            heapq.heappush(pq, (next_cost, next_basin, next_path, next_seen))
    return [], np.inf

def _open_sea_group(origin_basin, destination_basin):
    if origin_basin == "BLACK_SEA" or destination_basin == "BLACK_SEA":
        return "BLACK_SEA_REGIONAL"
    if origin_basin in {"MEDITERRANEAN", "NORTH_ATLANTIC_EUROPE", "BALTIC"} and \
       destination_basin in {"MEDITERRANEAN", "NORTH_ATLANTIC_EUROPE", "BALTIC", "ATLANTIC"}:
        return "EUROPEAN_MARITIME"
    return "DIRECT_OR_OPEN_SEA"

def _route_group(cp_sequence, origin_basin, destination_basin):
    if not cp_sequence:
        return _open_sea_group(origin_basin, destination_basin)
    txt = "|".join(cp_sequence).lower()
    if "hormuz"        in txt: return "HORMUZ_EXPOSED"
    if "suez"          in txt: return "SUEZ_EXPOSED"
    if "panama"        in txt: return "PANAMA_EXPOSED"
    if "malacca"       in txt: return "MALACCA_EXPOSED"
    if "gibraltar"     in txt: return "GIBRALTAR_EXPOSED"
    if "turkish"       in txt: return "BLACK_SEA_EXIT_EXPOSED"
    if "cape of good"  in txt: return "CAPE_REROUTED"
    return "OTHER_ROUTE"

_headline_exposure_group = _route_group

# ---------------------------------------------------------------------------
# Corridor-aware port ordering
# ---------------------------------------------------------------------------

_PREFERRED_REPORTER_BASIN = {
    ("FRA", "MEDITERRANEAN"): ["MEDITERRANEAN"],
    ("FRA", "RED_SEA"): ["MEDITERRANEAN"],
    ("FRA", "INDIAN_OCEAN"): ["MEDITERRANEAN"],
    ("FRA", "ARABIAN_SEA"): ["MEDITERRANEAN"],
    ("FRA", "GULF"): ["MEDITERRANEAN"],
    ("FRA", "WESTERN_PACIFIC"): ["MEDITERRANEAN"],
    ("FRA", "EAST_AFRICA_INDIAN"): ["MEDITERRANEAN"],
    ("FRA", "ATLANTIC"): ["NORTH_ATLANTIC_EUROPE"],
    ("FRA", "NORTH_AMERICA_ATLANTIC"): ["NORTH_ATLANTIC_EUROPE"],
    ("FRA", "CARIBBEAN"): ["NORTH_ATLANTIC_EUROPE"],
    ("FRA", "SOUTH_ATLANTIC"): ["NORTH_ATLANTIC_EUROPE"],
    ("FRA", "WEST_AFRICA_ATLANTIC"): ["NORTH_ATLANTIC_EUROPE"],
    ("FRA", "PACIFIC"): ["NORTH_ATLANTIC_EUROPE"],

    ("ESP", "MEDITERRANEAN"): ["MEDITERRANEAN"],
    ("ESP", "RED_SEA"): ["MEDITERRANEAN"],
    ("ESP", "INDIAN_OCEAN"): ["MEDITERRANEAN"],
    ("ESP", "ARABIAN_SEA"): ["MEDITERRANEAN"],
    ("ESP", "GULF"): ["MEDITERRANEAN"],
    ("ESP", "WESTERN_PACIFIC"): ["MEDITERRANEAN"],
    ("ESP", "EAST_AFRICA_INDIAN"): ["MEDITERRANEAN"],
    ("ESP", "ATLANTIC"): ["NORTH_ATLANTIC_EUROPE", "ATLANTIC"],
    ("ESP", "NORTH_AMERICA_ATLANTIC"): ["NORTH_ATLANTIC_EUROPE", "ATLANTIC"],
    ("ESP", "CARIBBEAN"): ["NORTH_ATLANTIC_EUROPE", "ATLANTIC"],
    ("ESP", "SOUTH_ATLANTIC"): ["NORTH_ATLANTIC_EUROPE", "ATLANTIC"],
    ("ESP", "WEST_AFRICA_ATLANTIC"): ["NORTH_ATLANTIC_EUROPE", "ATLANTIC"],
    ("ESP", "PACIFIC"): ["NORTH_ATLANTIC_EUROPE", "ATLANTIC"],
    ("ESP", "SOUTH_AMERICA_PACIFIC"): ["NORTH_ATLANTIC_EUROPE", "ATLANTIC"],

    ("ITA", "ATLANTIC"): ["MEDITERRANEAN"],
    ("ITA", "NORTH_AMERICA_ATLANTIC"): ["MEDITERRANEAN"],

    ("GRC", "ATLANTIC"): ["MEDITERRANEAN"],
    ("GRC", "NORTH_AMERICA_ATLANTIC"): ["MEDITERRANEAN"],
}

def _reorder_by_corridor(iso3, dest_basin, ports):
    preferred_basins = _PREFERRED_REPORTER_BASIN.get((iso3, dest_basin))
    if not preferred_basins:
        return ports
    preferred = [p for p in ports if p["port_basin"] in preferred_basins]
    others = [p for p in ports if p["port_basin"] not in preferred_basins]
    return preferred + others

def choose_gateway_iso3(iso3, partner_iso3=None):
    gateways = LANDLOCKED_GATEWAYS.get(iso3, [])
    if partner_iso3 in gateways:
        return partner_iso3
    return gateways[0] if gateways else None

def candidate_ports_for_iso3(iso3, partner_iso3=None, partner_basin=None):
    flags = COUNTRY_FLAGS.get(iso3, {})
    if flags.get("has_wpi_ports", False):
        ports = COUNTRY_PORTS.get(iso3, [])
        if partner_basin:
            ports = _reorder_by_corridor(iso3, partner_basin, ports)
        return ports, None, "DIRECT_PORT"
    if flags.get("is_landlocked_assumed", False):
        gw = choose_gateway_iso3(iso3, partner_iso3)
        if gw and gw in COUNTRY_PORTS:
            return COUNTRY_PORTS[gw], gw, "SEA_GATEWAY_INFERRED"
        return [], None, "LANDLOCKED_NO_GATEWAY"
    return [], None, "COASTAL_NO_PORT_MATCH"

def choose_best_port_pair(reporter_iso3, partner_iso3):
    partner_ports_raw, partner_gw, partner_basis = candidate_ports_for_iso3(
        partner_iso3, reporter_iso3, partner_basin=None
    )
    if not partner_ports_raw:
        return None

    partner_basin_hint = partner_ports_raw[0]["port_basin"] if partner_ports_raw else None

    reporter_ports, reporter_gw, reporter_basis = candidate_ports_for_iso3(
        reporter_iso3, partner_iso3, partner_basin=partner_basin_hint
    )
    if not reporter_ports:
        return None

    best = None
    best_score = -np.inf

    for rp in reporter_ports:
        for pp in partner_ports_raw:
            gc_km = _gc_distance_km(rp["lonlat"], pp["lonlat"])
            cp_sequence, basin_cost = shortest_basin_path(rp["port_basin"], pp["port_basin"])

            neighbour_penalty = 0.0
            if gc_km < 1500 and len(cp_sequence) >= 2:
                neighbour_penalty += 8.0
            if gc_km < 2500 and any(
                cp in cp_sequence for cp in ["Suez Canal", "Hormuz Strait", "Bab el-Mandeb"]
            ):
                neighbour_penalty += 8.0

            corridor_penalty = _corridor_penalty(cp_sequence, rp["port_basin"], pp["port_basin"])

            direction_bonus = 0.0

            east_of_suez_basins = {
                "RED_SEA", "ARABIAN_SEA", "GULF",
                "INDIAN_OCEAN", "WESTERN_PACIFIC", "PACIFIC"
            }

            atlantic_side_basins = {
                "ATLANTIC", "NORTH_ATLANTIC_EUROPE",
                "NORTH_AMERICA_ATLANTIC",
                "CARIBBEAN", "SOUTH_ATLANTIC", "WEST_AFRICA_ATLANTIC"
            }

            if pp["port_basin"] in east_of_suez_basins:
                direction_bonus += rp.get("eastbound_corridor_fit", 0.0)
                direction_bonus -= pp.get("atlantic_corridor_fit", 0.0) * 0.15

            if pp["port_basin"] in atlantic_side_basins:
                direction_bonus += rp.get("atlantic_corridor_fit", 0.0)
                direction_bonus -= pp.get("eastbound_corridor_fit", 0.0) * 0.15

            if reporter_iso3 == "FRA" and pp["port_basin"] in east_of_suez_basins:
                if rp["port_basin"] == "MEDITERRANEAN":
                    direction_bonus += 6.0
                elif rp["port_basin"] in {"ATLANTIC", "NORTH_ATLANTIC_EUROPE"}:
                    direction_bonus -= 6.0

            if reporter_iso3 == "ESP" and pp["port_basin"] in east_of_suez_basins:
                if rp["port_basin"] == "MEDITERRANEAN":
                    direction_bonus += 4.0
                elif rp["port_basin"] in {"ATLANTIC", "NORTH_ATLANTIC_EUROPE"}:
                    direction_bonus -= 4.0

            pair_score = (
                rp["port_score"] * 0.20
                + pp["port_score"] * 0.20
                - gc_km * 0.0012
                - basin_cost * 1.30
                - neighbour_penalty
                - corridor_penalty
                + direction_bonus
            )

            candidate = {
                "reporter_port": rp["port_name"],
                "partner_port": pp["port_name"],
                "reporter_lonlat": rp["lonlat"],
                "partner_lonlat": pp["lonlat"],
                "reporter_basin": rp["port_basin"],
                "partner_basin": pp["port_basin"],
                "reporter_gateway_iso3": reporter_gw,
                "partner_gateway_iso3": partner_gw,
                "reporter_port_basis": reporter_basis,
                "partner_port_basis": partner_basis,
                "distance_km": gc_km,
                "cp_sequence": cp_sequence,
                "pair_score": pair_score,
            }

            if pair_score > best_score:
                best = candidate
                best_score = pair_score

    return best

def maybe_assign_hub(origin_basin, destination_basin):
    hits = bridge_basin_default_hubs[
        (bridge_basin_default_hubs["origin_basin"] == origin_basin)
        & (bridge_basin_default_hubs["destination_basin"] == destination_basin)
    ].sort_values("hub_rank")
    if hits.empty:
        return None
    return HUB_BY_BASIN.get(hits.iloc[0]["hub_basin"])

def _forced_path_distance(start_lonlat, end_lonlat, chokepoints):
    if not chokepoints:
        dist_km, route = _sea_distance_km(start_lonlat, end_lonlat)
        return dist_km, route["geometry"]["coordinates"]

    path_nodes = (
        [start_lonlat]
        + [CHOKEPOINT_COORDS[cp] for cp in chokepoints if cp in CHOKEPOINT_COORDS]
        + [end_lonlat]
    )

    total_km = 0.0
    stitched = []

    for i in range(len(path_nodes) - 1):
        leg_km, leg_route = _sea_distance_km(path_nodes[i], path_nodes[i + 1])
        total_km += leg_km
        leg_coords = leg_route["geometry"]["coordinates"]
        if i == 0:
            stitched.extend(leg_coords)
        else:
            stitched.extend(leg_coords[1:])

    return total_km, stitched

def _assign_confidence(reporter_iso3,
                       reporter_port_basis, partner_port_basis,
                       reporter_basin, partner_basin,
                       cp_sequence, gc_km, route_scenario):
    score = 2  # 0=very_low, 1=low, 2=medium, 3=high

    if reporter_port_basis != "DIRECT_PORT" or partner_port_basis != "DIRECT_PORT":
        score = min(score, 1)

    if reporter_basin == "UNKNOWN_COASTAL" or partner_basin == "UNKNOWN_COASTAL":
        score = min(score, 0)

    if gc_km < 1200 and any(
        cp in cp_sequence
        for cp in ["Suez Canal", "Hormuz Strait", "Bab el-Mandeb", "Panama Canal"]
    ):
        score = min(score, 0)

    if route_scenario == "default_shortest":
        cp_txt = "|".join(cp_sequence).lower()

        if reporter_basin in SUEZ_ORIGIN_BASINS and partner_basin in EAST_OF_SUEZ_BASINS:
            if "panama" in cp_txt:
                score = 0
            elif "cape of good hope" in cp_txt:
                score = min(score, 1)

        if reporter_port_basis == "DIRECT_PORT" and reporter_iso3 == "FRA":
            if reporter_basin in {"ATLANTIC", "NORTH_ATLANTIC_EUROPE"} and partner_basin in EAST_OF_SUEZ_BASINS:
                score = min(score, 1)

    return {0: "very_low", 1: "low", 2: "medium", 3: "high"}[score]

# ---------------------------------------------------------------------------
# Decide which candidate pairs should be routed
# ---------------------------------------------------------------------------

route_candidates = route_candidates.copy()
route_candidates["routing_decision"] = route_candidates.apply(assign_routing_decision, axis=1)

to_route = route_candidates[
    route_candidates["routing_decision"].isin(["route_by_observed_sea", "route_by_inference"])
].copy()

to_route["_key"] = list(
    to_route[["reporter_iso3", "partner_iso3", "partner2_iso3"]]
    .fillna("__NULL__")
    .itertuples(index=False, name=None)
)

if existing_keys:
    to_route = to_route[~to_route["_key"].isin(existing_keys)].copy()

display(
    route_candidates["routing_decision"]
    .value_counts(dropna=False)
    .rename_axis("routing_decision")
    .reset_index(name="route_count")
)

display(to_route.head(10))
print("Keys selected for routing:", len(to_route))

# ---------------------------------------------------------------------------
# Main routing loop
# ---------------------------------------------------------------------------

records = []

for row in to_route.itertuples(index=False):
    r_iso = row.reporter_iso3
    p_iso = row.partner_iso3
    p2_iso = row.partner2_iso3 if pd.notna(row.partner2_iso3) else None

    best = choose_best_port_pair(r_iso, p_iso)

    if best is None:
        records.append({
            "reporter_iso3": r_iso,
            "partner_iso3": p_iso,
            "partner2_iso3": p2_iso,
            "transport_evidence": row.transport_evidence,
            "routing_decision": row.routing_decision,
            "route_status": "UNROUTED",
            "route_basis": "NO_PORT_PATH",
            "reporter_port": None,
            "partner_port": None,
            "reporter_gateway_iso3": None,
            "partner_gateway_iso3": None,
            "reporter_basin": None,
            "partner_basin": None,
            "distance_km": np.nan,
            "sea_distance_km": np.nan,
            "sea_distance_direct_km": np.nan,
            "sea_distance_forced_km": np.nan,
            "first_chokepoint": None,
            "last_chokepoint": None,
            "chokepoint_sequence": None,
            "chokepoint_sequence_str": None,
            "headline_exposure_group": "UNROUTED",
            "main_chokepoint": None,
            "route_group": "UNROUTED",
            "route_mode": "unrouted",
            "route_confidence": "very_low",
            "route_applicability_status": row.transport_evidence,  # backwards-compatible only
            "mot_codes_seen": row.mot_codes_seen,
            "route_scenario": ROUTE_SCENARIO,
            "used_transshipment_hub": False,
            "hub_port": None,
            "hub_iso3": None,
            "hub_basin": None,
            "route_path_coords": [],
        })
        continue

    sea_direct_km = np.nan
    direct_coords = []

    try:
        sea_direct_km, direct_route = _sea_distance_km(best["reporter_lonlat"], best["partner_lonlat"])
        direct_coords = direct_route["geometry"]["coordinates"]
    except Exception:
        pass

    cp_sequence = best["cp_sequence"]
    sea_forced_km = np.nan
    route_coords = direct_coords

    if cp_sequence:
        try:
            sea_forced_km, route_coords = _forced_path_distance(
                best["reporter_lonlat"], best["partner_lonlat"], cp_sequence
            )
        except Exception:
            pass

    sea_km = sea_forced_km if np.isfinite(sea_forced_km) else sea_direct_km
    route_mode = "forced_chokepoint" if cp_sequence else "direct"

    first_cp = cp_sequence[0] if cp_sequence else None
    last_cp = cp_sequence[-1] if cp_sequence else None
    cp_seq_str = " -> ".join(cp_sequence) if cp_sequence else None

    hub_choice = maybe_assign_hub(best["reporter_basin"], best["partner_basin"])
    used_hub = (
        hub_choice is not None
        and best["distance_km"] > 2000
        and best["reporter_basin"] != best["partner_basin"]
    )

    route_confidence = _assign_confidence(
        reporter_iso3=r_iso,
        reporter_port_basis=best["reporter_port_basis"],
        partner_port_basis=best["partner_port_basis"],
        reporter_basin=best["reporter_basin"],
        partner_basin=best["partner_basin"],
        cp_sequence=cp_sequence,
        gc_km=best["distance_km"],
        route_scenario=ROUTE_SCENARIO,
    )

    route_basis_parts = []

    if row.routing_decision == "route_by_observed_sea":
        route_basis_parts.append("SEA_OBSERVED_MOTCODE")
    elif row.routing_decision == "route_by_inference":
        route_basis_parts.append("SEA_INFERRED_FROM_UNKNOWN_TRANSPORT")

    route_basis_parts.append(ROUTE_SCENARIO)

    if best["reporter_port_basis"] != "DIRECT_PORT":
        route_basis_parts.append(best["reporter_port_basis"])
    if best["partner_port_basis"] != "DIRECT_PORT":
        route_basis_parts.append(best["partner_port_basis"])
    if used_hub:
        route_basis_parts.append("OPTIONAL_HUB_INFERRED")

    rg = _route_group(cp_sequence, best["reporter_basin"], best["partner_basin"])
    heg = _headline_exposure_group(cp_sequence, best["reporter_basin"], best["partner_basin"])

    records.append({
        "reporter_iso3": r_iso,
        "partner_iso3": p_iso,
        "partner2_iso3": p2_iso,
        "reporter_port": best["reporter_port"],
        "partner_port": best["partner_port"],
        "reporter_gateway_iso3": best["reporter_gateway_iso3"],
        "partner_gateway_iso3": best["partner_gateway_iso3"],
        "reporter_basin": best["reporter_basin"],
        "partner_basin": best["partner_basin"],
        "distance_km": round(best["distance_km"], 2),
        "sea_distance_km": round(sea_km, 2) if np.isfinite(sea_km) else np.nan,
        "sea_distance_direct_km": round(sea_direct_km, 2) if np.isfinite(sea_direct_km) else np.nan,
        "sea_distance_forced_km": round(sea_forced_km, 2) if np.isfinite(sea_forced_km) else np.nan,
        "first_chokepoint": first_cp,
        "last_chokepoint": last_cp,
        "chokepoint_sequence": cp_sequence,
        "chokepoint_sequence_str": cp_seq_str,
        "headline_exposure_group": heg,
        "main_chokepoint": first_cp,
        "route_group": rg,
        "route_mode": route_mode,
        "route_status": "ROUTED",
        "route_basis": "|".join(route_basis_parts),
        "route_confidence": route_confidence,
        "route_applicability_status": row.transport_evidence,  # backwards-compatible only
        "transport_evidence": row.transport_evidence,
        "routing_decision": row.routing_decision,
        "mot_codes_seen": row.mot_codes_seen,
        "route_scenario": ROUTE_SCENARIO,
        "used_transshipment_hub": used_hub,
        "hub_port": hub_choice.get("hub_port") if used_hub else None,
        "hub_iso3": hub_choice.get("hub_iso3") if used_hub else None,
        "hub_basin": hub_choice.get("hub_basin") if used_hub else None,
        "route_path_coords": route_coords,
    })

dim_trade_routes_new = pd.DataFrame.from_records(records)

display(dim_trade_routes_new[[
    "reporter_iso3", "partner_iso3", "reporter_port", "partner_port",
    "reporter_basin", "partner_basin",
    "first_chokepoint", "last_chokepoint", "chokepoint_sequence",
    "headline_exposure_group", "route_confidence",
    "transport_evidence", "routing_decision", "route_basis"
]].head(30))

display(
    dim_trade_routes_new["headline_exposure_group"]
    .value_counts(dropna=False)
    .rename_axis("headline_exposure_group")
    .reset_index(name="route_count")
)

display(
    dim_trade_routes_new["route_confidence"]
    .value_counts(dropna=False)
    .rename_axis("route_confidence")
    .reset_index(name="route_count")
)

display(
    dim_trade_routes_new["routing_decision"]
    .value_counts(dropna=False)
    .rename_axis("routing_decision")
    .reset_index(name="route_count")
)
# Out:
#         routing_decision  route_count
# 0  route_by_observed_sea         1373
# 1     route_by_inference          900
# 2           do_not_route          624
#    reporter_iso3 partner_iso3  partner2_iso3  row_count  trade_value_usd  \
# 0            BGR          AGO            NaN         16     1.117763e+06
# 1            BGR          ALB            NaN        528     6.187100e+08
# 2            BGR          ARE            NaN        250     1.508292e+08
# 3            BGR          ARG            NaN        341     1.413164e+07
# 4            BGR          ARM            NaN        238     1.966293e+07
# 5            BGR          ATG            NaN         24     5.069904e+05
# 6            BGR          AUS            NaN        106     3.912566e+06
# 8            BGR          AZE            NaN        250     6.370388e+08
# 9            BGR          BEL            NaN       1394     6.942962e+08
# 11           BGR          BGD            NaN         36     5.387316e+08
#
#     has_sea  has_inland_water  has_unknown  has_non_marine  \
# 0      True             False         True            True
# 1      True             False         True            True
# 2      True              True         True            True
# 3      True             False         True            True
# 4      True             False         True            True
# 5      True             False         True            True
# 6      True             False         True            True
# 8      True             False         True            True
# 9      True             False         True            True
# 11     True             False         True            True
#
#                 mot_codes_seen transport_evidence       routing_decision  \
# 0                  0|1000|2100       sea_observed  route_by_observed_sea
# 1             0|1000|2100|3200       sea_observed  route_by_observed_sea
# 2        0|1000|2100|2200|3200       sea_observed  route_by_observed_sea
# 3        0|1000|2100|3100|3200       sea_observed  route_by_observed_sea
# 4                  0|2100|3200       sea_observed  route_by_observed_sea
# 5                  0|2100|3200       sea_observed  route_by_observed_sea
# 6             0|1000|2100|3200       sea_observed  route_by_observed_sea
# 8        0|1000|2100|3100|3200       sea_observed  route_by_observed_sea
# 9   0|1000|2100|3100|3200|9200       sea_observed  route_by_observed_sea
# 11                 0|1000|2100       sea_observed  route_by_observed_sea
#
#                     _key
# 0   (BGR, AGO, __NULL__)
# 1   (BGR, ALB, __NULL__)
# 2   (BGR, ARE, __NULL__)
# 3   (BGR, ARG, __NULL__)
# 4   (BGR, ARM, __NULL__)
# 5   (BGR, ATG, __NULL__)
# 6   (BGR, AUS, __NULL__)
# 8   (BGR, AZE, __NULL__)
# 9   (BGR, BEL, __NULL__)
# 11  (BGR, BGD, __NULL__)
# Keys selected for routing: 2273
#    reporter_iso3 partner_iso3 reporter_port          partner_port  \
# 0            BGR          AGO         Varna  Malongo Oil Terminal
# 1            BGR          ALB         Varna                Durres
# 2            BGR          ARE         Varna           Al Fujayrah
# 3            BGR          ARG         Varna          Buenos Aires
# 4            BGR          ARM         Varna          Bandar Abbas
# 5            BGR          ATG         Varna              St Johns
# 6            BGR          AUS         Varna             Fremantle
# 7            BGR          AZE         Varna          Novorossiysk
# 8            BGR          BEL         Varna             Antwerpen
# 9            BGR          BGD         Varna            Chittagong
# 10           BGR          BHR         Varna           Mina Salman
# 11           BGR          BHS         Varna                Nassau
# 12           BGR          BLZ         Varna           Belize City
# 13           BGR          BRA         Varna               Tubarao
# 14           BGR          BRB         Varna            Bridgetown
# 15           BGR          CAN         Varna              Argentia
# 16           BGR          CHL         Varna       Puerto Williams
# 17           BGR          CHN         Varna      Tianjin Xin Gang
# 18           BGR          CMR         Varna                Douala
# 19           BGR          COK         Varna                Avatiu
# 20           BGR          COL         Varna          Barranquilla
# 21           BGR          COM         Varna                Moroni
# 22           BGR          CYM         Varna            Georgetown
# 23           BGR          CYP         Varna             Famagusta
# 24           BGR          DEU         Varna                  Kiel
# 25           BGR          DNK         Varna             Kobenhavn
# 26           BGR          DOM         Varna         Santo Domingo
# 27           BGR          DZA         Varna                 Alger
# 28           BGR          E19         Varna                 Varna
# 29           BGR          EGY         Varna              Damietta
#
#    reporter_basin           partner_basin first_chokepoint   last_chokepoint  \
# 0       BLACK_SEA          SOUTH_ATLANTIC  Turkish Straits  Gibraltar Strait
# 1       BLACK_SEA           MEDITERRANEAN  Turkish Straits   Turkish Straits
# 2       BLACK_SEA            INDIAN_OCEAN  Turkish Straits     Bab el-Mandeb
# 3       BLACK_SEA          SOUTH_ATLANTIC  Turkish Straits  Gibraltar Strait
# 4       BLACK_SEA            INDIAN_OCEAN  Turkish Straits     Bab el-Mandeb
# 5       BLACK_SEA               CARIBBEAN  Turkish Straits  Gibraltar Strait
# 6       BLACK_SEA            INDIAN_OCEAN  Turkish Straits     Bab el-Mandeb
# 7       BLACK_SEA               BLACK_SEA              NaN               NaN
# 8       BLACK_SEA   NORTH_ATLANTIC_EUROPE  Turkish Straits  Gibraltar Strait
# 9       BLACK_SEA            INDIAN_OCEAN  Turkish Straits     Bab el-Mandeb
# 10      BLACK_SEA                    GULF  Turkish Straits     Hormuz Strait
# 11      BLACK_SEA  NORTH_AMERICA_ATLANTIC  Turkish Straits  Gibraltar Strait
# 12      BLACK_SEA               CARIBBEAN  Turkish Straits  Gibraltar Strait
# 13      BLACK_SEA          SOUTH_ATLANTIC  Turkish Straits  Gibraltar Strait
# 14      BLACK_SEA  NORTH_AMERICA_ATLANTIC  Turkish Straits  Gibraltar Strait
# 15      BLACK_SEA  NORTH_AMERICA_ATLANTIC  Turkish Straits  Gibraltar Strait
# 16      BLACK_SEA          SOUTH_ATLANTIC  Turkish Straits  Gibraltar Strait
# 17      BLACK_SEA         WESTERN_PACIFIC  Turkish Straits    Malacca Strait
# 18      BLACK_SEA                ATLANTIC  Turkish Straits  Gibraltar Strait
# 19      BLACK_SEA   SOUTH_AMERICA_PACIFIC  Turkish Straits    Malacca Strait
# 20      BLACK_SEA               CARIBBEAN  Turkish Straits  Gibraltar Strait
# 21      BLACK_SEA            INDIAN_OCEAN  Turkish Straits     Bab el-Mandeb
# 22      BLACK_SEA               CARIBBEAN  Turkish Straits  Gibraltar Strait
# 23      BLACK_SEA           MEDITERRANEAN  Turkish Straits   Turkish Straits
# 24      BLACK_SEA                  BALTIC  Turkish Straits  Gibraltar Strait
# 25      BLACK_SEA                  BALTIC  Turkish Straits  Gibraltar Strait
# 26      BLACK_SEA               CARIBBEAN  Turkish Straits  Gibraltar Strait
# 27      BLACK_SEA           MEDITERRANEAN  Turkish Straits   Turkish Straits
# 28      BLACK_SEA               BLACK_SEA              NaN               NaN
# 29      BLACK_SEA           MEDITERRANEAN  Turkish Straits   Turkish Straits
#
#                                   chokepoint_sequence headline_exposure_group  \
# 0                 [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 1                                   [Turkish Straits]  BLACK_SEA_EXIT_EXPOSED
# 2        [Turkish Straits, Suez Canal, Bab el-Mandeb]            SUEZ_EXPOSED
# 3                 [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 4        [Turkish Straits, Suez Canal, Bab el-Mandeb]            SUEZ_EXPOSED
# 5                 [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 6        [Turkish Straits, Suez Canal, Bab el-Mandeb]            SUEZ_EXPOSED
# 7                                                  []      BLACK_SEA_REGIONAL
# 8                 [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 9        [Turkish Straits, Suez Canal, Bab el-Mandeb]            SUEZ_EXPOSED
# 10  [Turkish Straits, Suez Canal, Bab el-Mandeb, H...          HORMUZ_EXPOSED
# 11                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 12                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 13                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 14                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 15                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 16                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 17  [Turkish Straits, Suez Canal, Bab el-Mandeb, M...            SUEZ_EXPOSED
# 18                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 19  [Turkish Straits, Suez Canal, Bab el-Mandeb, M...            SUEZ_EXPOSED
# 20                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 21       [Turkish Straits, Suez Canal, Bab el-Mandeb]            SUEZ_EXPOSED
# 22                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 23                                  [Turkish Straits]  BLACK_SEA_EXIT_EXPOSED
# 24                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 25                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 26                [Turkish Straits, Gibraltar Strait]       GIBRALTAR_EXPOSED
# 27                                  [Turkish Straits]  BLACK_SEA_EXIT_EXPOSED
# 28                                                 []      BLACK_SEA_REGIONAL
# 29                                  [Turkish Straits]  BLACK_SEA_EXIT_EXPOSED
#
#    route_confidence transport_evidence       routing_decision  \
# 0            medium       sea_observed  route_by_observed_sea
# 1            medium       sea_observed  route_by_observed_sea
# 2            medium       sea_observed  route_by_observed_sea
# 3            medium       sea_observed  route_by_observed_sea
# 4               low       sea_observed  route_by_observed_sea
# 5            medium       sea_observed  route_by_observed_sea
# 6            medium       sea_observed  route_by_observed_sea
# 7               low       sea_observed  route_by_observed_sea
# 8            medium       sea_observed  route_by_observed_sea
# 9            medium       sea_observed  route_by_observed_sea
# 10           medium       sea_observed  route_by_observed_sea
# 11           medium       sea_observed  route_by_observed_sea
# 12           medium       sea_observed  route_by_observed_sea
# 13           medium       sea_observed  route_by_observed_sea
# 14           medium       sea_observed  route_by_observed_sea
# 15           medium       sea_observed  route_by_observed_sea
# 16           medium       sea_observed  route_by_observed_sea
# 17           medium       sea_observed  route_by_observed_sea
# 18           medium       sea_observed  route_by_observed_sea
# 19           medium       sea_observed  route_by_observed_sea
# 20           medium       sea_observed  route_by_observed_sea
# 21           medium       sea_observed  route_by_observed_sea
# 22           medium       sea_observed  route_by_observed_sea
# 23           medium       sea_observed  route_by_observed_sea
# 24           medium       sea_observed  route_by_observed_sea
# 25           medium       sea_observed  route_by_observed_sea
# 26           medium       sea_observed  route_by_observed_sea
# 27           medium       sea_observed  route_by_observed_sea
# 28              low       sea_observed  route_by_observed_sea
# 29           medium       sea_observed  route_by_observed_sea
#
#                                           route_basis
# 0               SEA_OBSERVED_MOTCODE|default_shortest
# 1               SEA_OBSERVED_MOTCODE|default_shortest
# 2               SEA_OBSERVED_MOTCODE|default_shortest
# 3               SEA_OBSERVED_MOTCODE|default_shortest
# 4   SEA_OBSERVED_MOTCODE|default_shortest|SEA_GATE...
# 5               SEA_OBSERVED_MOTCODE|default_shortest
# 6               SEA_OBSERVED_MOTCODE|default_shortest
# 7   SEA_OBSERVED_MOTCODE|default_shortest|SEA_GATE...
# 8               SEA_OBSERVED_MOTCODE|default_shortest
# 9               SEA_OBSERVED_MOTCODE|default_shortest
# 10              SEA_OBSERVED_MOTCODE|default_shortest
# 11  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...
# 12              SEA_OBSERVED_MOTCODE|default_shortest
# 13              SEA_OBSERVED_MOTCODE|default_shortest
# 14  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...
# 15  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...
# 16              SEA_OBSERVED_MOTCODE|default_shortest
# 17  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...
# 18  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...
# 19              SEA_OBSERVED_MOTCODE|default_shortest
# 20              SEA_OBSERVED_MOTCODE|default_shortest
# 21              SEA_OBSERVED_MOTCODE|default_shortest
# 22              SEA_OBSERVED_MOTCODE|default_shortest
# 23              SEA_OBSERVED_MOTCODE|default_shortest
# 24              SEA_OBSERVED_MOTCODE|default_shortest
# 25              SEA_OBSERVED_MOTCODE|default_shortest
# 26              SEA_OBSERVED_MOTCODE|default_shortest
# 27              SEA_OBSERVED_MOTCODE|default_shortest
# 28  SEA_OBSERVED_MOTCODE|default_shortest|SEA_GATE...
# 29              SEA_OBSERVED_MOTCODE|default_shortest
#    headline_exposure_group  route_count
# 0       DIRECT_OR_OPEN_SEA          788
# 1             SUEZ_EXPOSED          489
# 2        GIBRALTAR_EXPOSED          337
# 3          MALACCA_EXPOSED          167
# 4        EUROPEAN_MARITIME          141
# 5           PANAMA_EXPOSED          102
# 6           HORMUZ_EXPOSED           58
# 7   BLACK_SEA_EXIT_EXPOSED           57
# 8            CAPE_REROUTED           44
# 9       BLACK_SEA_REGIONAL           43
# 10             OTHER_ROUTE           35
# 11                UNROUTED           12
#   route_confidence  route_count
# 0           medium         2025
# 1              low          235
# 2         very_low           13
#         routing_decision  route_count
# 0  route_by_observed_sea         1373
# 1     route_by_inference          900

# %%
# derive a human-readable basin-path bridge for auditability
audit_records = []

for row in dim_trade_routes_new.itertuples(index=False):
    cps = row.chokepoint_sequence if isinstance(row.chokepoint_sequence, list) else []

    if not cps:
        audit_records.append(
            {
                "reporter_iso3": row.reporter_iso3,
                "partner_iso3": row.partner_iso3,
                "origin_basin": row.reporter_basin,
                "destination_basin": row.partner_basin,
                "leg_order": 0,
                "chokepoint_name": "Open Sea / Same Basin",
                "headline_chokepoint": row.first_chokepoint if hasattr(row, "first_chokepoint") else None,
                "headline_exposure_group": row.headline_exposure_group,
                "route_confidence": row.route_confidence,
            }
        )
    else:
        for idx, cp in enumerate(cps, start=1):
            audit_records.append(
                {
                    "reporter_iso3": row.reporter_iso3,
                    "partner_iso3": row.partner_iso3,
                    "origin_basin": row.reporter_basin,
                    "destination_basin": row.partner_basin,
                    "leg_order": idx,
                    "chokepoint_name": cp,
                    "headline_chokepoint": row.first_chokepoint if hasattr(row, "first_chokepoint") else cps[0],
                    "headline_exposure_group": row.headline_exposure_group,
                    "route_confidence": row.route_confidence,
                }
            )

bridge_port_basin_chokepoints = pd.DataFrame(audit_records).sort_values(
    ["reporter_iso3", "partner_iso3", "origin_basin", "destination_basin", "leg_order"]
)

bridge_port_basin_chokepoints.to_parquet(BASIN_PATH_RULES_PATH, index=False)
display(bridge_port_basin_chokepoints.head(40))
# Out:
#    reporter_iso3 partner_iso3 origin_basin       destination_basin  leg_order  \
# 0            BGR          AGO    BLACK_SEA          SOUTH_ATLANTIC          1
# 1            BGR          AGO    BLACK_SEA          SOUTH_ATLANTIC          2
# 2            BGR          ALB    BLACK_SEA           MEDITERRANEAN          1
# 3            BGR          ARE    BLACK_SEA            INDIAN_OCEAN          1
# 4            BGR          ARE    BLACK_SEA            INDIAN_OCEAN          2
# 5            BGR          ARE    BLACK_SEA            INDIAN_OCEAN          3
# 6            BGR          ARG    BLACK_SEA          SOUTH_ATLANTIC          1
# 7            BGR          ARG    BLACK_SEA          SOUTH_ATLANTIC          2
# 8            BGR          ARM    BLACK_SEA            INDIAN_OCEAN          1
# 9            BGR          ARM    BLACK_SEA            INDIAN_OCEAN          2
# 10           BGR          ARM    BLACK_SEA            INDIAN_OCEAN          3
# 11           BGR          ATG    BLACK_SEA               CARIBBEAN          1
# 12           BGR          ATG    BLACK_SEA               CARIBBEAN          2
# 13           BGR          AUS    BLACK_SEA            INDIAN_OCEAN          1
# 14           BGR          AUS    BLACK_SEA            INDIAN_OCEAN          2
# 15           BGR          AUS    BLACK_SEA            INDIAN_OCEAN          3
# 16           BGR          AZE    BLACK_SEA               BLACK_SEA          0
# 17           BGR          BEL    BLACK_SEA   NORTH_ATLANTIC_EUROPE          1
# 18           BGR          BEL    BLACK_SEA   NORTH_ATLANTIC_EUROPE          2
# 19           BGR          BGD    BLACK_SEA            INDIAN_OCEAN          1
# 20           BGR          BGD    BLACK_SEA            INDIAN_OCEAN          2
# 21           BGR          BGD    BLACK_SEA            INDIAN_OCEAN          3
# 22           BGR          BHR    BLACK_SEA                    GULF          1
# 23           BGR          BHR    BLACK_SEA                    GULF          2
# 24           BGR          BHR    BLACK_SEA                    GULF          3
# 25           BGR          BHR    BLACK_SEA                    GULF          4
# 26           BGR          BHS    BLACK_SEA  NORTH_AMERICA_ATLANTIC          1
# 27           BGR          BHS    BLACK_SEA  NORTH_AMERICA_ATLANTIC          2
# 28           BGR          BLZ    BLACK_SEA               CARIBBEAN          1
# 29           BGR          BLZ    BLACK_SEA               CARIBBEAN          2
# 30           BGR          BRA    BLACK_SEA          SOUTH_ATLANTIC          1
# 31           BGR          BRA    BLACK_SEA          SOUTH_ATLANTIC          2
# 32           BGR          BRB    BLACK_SEA  NORTH_AMERICA_ATLANTIC          1
# 33           BGR          BRB    BLACK_SEA  NORTH_AMERICA_ATLANTIC          2
# 34           BGR          CAN    BLACK_SEA  NORTH_AMERICA_ATLANTIC          1
# 35           BGR          CAN    BLACK_SEA  NORTH_AMERICA_ATLANTIC          2
# 36           BGR          CHL    BLACK_SEA          SOUTH_ATLANTIC          1
# 37           BGR          CHL    BLACK_SEA          SOUTH_ATLANTIC          2
# 38           BGR          CHN    BLACK_SEA         WESTERN_PACIFIC          1
# 39           BGR          CHN    BLACK_SEA         WESTERN_PACIFIC          2
#
#           chokepoint_name headline_chokepoint headline_exposure_group  \
# 0         Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 1        Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 2         Turkish Straits     Turkish Straits  BLACK_SEA_EXIT_EXPOSED
# 3         Turkish Straits     Turkish Straits            SUEZ_EXPOSED
# 4              Suez Canal     Turkish Straits            SUEZ_EXPOSED
# 5           Bab el-Mandeb     Turkish Straits            SUEZ_EXPOSED
# 6         Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 7        Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 8         Turkish Straits     Turkish Straits            SUEZ_EXPOSED
# 9              Suez Canal     Turkish Straits            SUEZ_EXPOSED
# 10          Bab el-Mandeb     Turkish Straits            SUEZ_EXPOSED
# 11        Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 12       Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 13        Turkish Straits     Turkish Straits            SUEZ_EXPOSED
# 14             Suez Canal     Turkish Straits            SUEZ_EXPOSED
# 15          Bab el-Mandeb     Turkish Straits            SUEZ_EXPOSED
# 16  Open Sea / Same Basin                 NaN      BLACK_SEA_REGIONAL
# 17        Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 18       Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 19        Turkish Straits     Turkish Straits            SUEZ_EXPOSED
# 20             Suez Canal     Turkish Straits            SUEZ_EXPOSED
# 21          Bab el-Mandeb     Turkish Straits            SUEZ_EXPOSED
# 22        Turkish Straits     Turkish Straits          HORMUZ_EXPOSED
# 23             Suez Canal     Turkish Straits          HORMUZ_EXPOSED
# 24          Bab el-Mandeb     Turkish Straits          HORMUZ_EXPOSED
# 25          Hormuz Strait     Turkish Straits          HORMUZ_EXPOSED
# 26        Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 27       Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 28        Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 29       Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 30        Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 31       Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 32        Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 33       Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 34        Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 35       Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 36        Turkish Straits     Turkish Straits       GIBRALTAR_EXPOSED
# 37       Gibraltar Strait     Turkish Straits       GIBRALTAR_EXPOSED
# 38        Turkish Straits     Turkish Straits            SUEZ_EXPOSED
# 39             Suez Canal     Turkish Straits            SUEZ_EXPOSED
#
#    route_confidence
# 0            medium
# 1            medium
# 2            medium
# 3            medium
# 4            medium
# 5            medium
# 6            medium
# 7            medium
# 8               low
# 9               low
# 10              low
# 11           medium
# 12           medium
# 13           medium
# 14           medium
# 15           medium
# 16              low
# 17           medium
# 18           medium
# 19           medium
# 20           medium
# 21           medium
# 22           medium
# 23           medium
# 24           medium
# 25           medium
# 26           medium
# 27           medium
# 28           medium
# 29           medium
# 30           medium
# 31           medium
# 32           medium
# 33           medium
# 34           medium
# 35           medium
# 36           medium
# 37           medium
# 38           medium
# 39           medium

# %%
# merge, deduplicate, and persist the refreshed dim_trade_routes
if FULL_REBUILD_DIM_TRADE_ROUTES or dim_trade_routes_existing.empty:
    dim_trade_routes = dim_trade_routes_new.copy()
else:
    combined = pd.concat(
        [
            dim_trade_routes_existing.reindex(columns=dim_trade_routes_new.columns),
            dim_trade_routes_new,
        ],
        ignore_index=True,
    )

    dim_trade_routes = combined.drop_duplicates(
        subset=["reporter_iso3", "partner_iso3", "partner2_iso3", "route_scenario"],
        keep="last",
    ).sort_values(
        ["reporter_iso3", "partner_iso3", "partner2_iso3", "route_scenario"],
        na_position="last"
    )

dim_trade_routes_export = dim_trade_routes.drop(columns=["route_path_coords"], errors="ignore").copy()
dim_trade_routes_export.to_parquet(DIM_OUTPUT_PATH, index=False)

display(dim_trade_routes["route_mode"].value_counts(dropna=False).rename_axis("route_mode").reset_index(name="route_count"))
display(dim_trade_routes["route_confidence"].value_counts(dropna=False).rename_axis("route_confidence").reset_index(name="route_count"))
display(dim_trade_routes.head(20))
print(DIM_OUTPUT_PATH)
# Out:
#           route_mode  route_count
# 0  forced_chokepoint         1289
# 1             direct          972
# 2           unrouted           12
#   route_confidence  route_count
# 0           medium         2025
# 1              low          235
# 2         very_low           13
#    reporter_iso3 partner_iso3 partner2_iso3 reporter_port  \
# 0            BGR          AGO          None         Varna
# 1            BGR          ALB          None         Varna
# 2            BGR          ARE          None         Varna
# 3            BGR          ARG          None         Varna
# 4            BGR          ARM          None         Varna
# 5            BGR          ATG          None         Varna
# 6            BGR          AUS          None         Varna
# 7            BGR          AZE          None         Varna
# 8            BGR          BEL          None         Varna
# 9            BGR          BGD          None         Varna
# 10           BGR          BHR          None         Varna
# 11           BGR          BHS          None         Varna
# 12           BGR          BLZ          None         Varna
# 13           BGR          BRA          None         Varna
# 14           BGR          BRB          None         Varna
# 15           BGR          CAN          None         Varna
# 16           BGR          CHL          None         Varna
# 17           BGR          CHN          None         Varna
# 18           BGR          CMR          None         Varna
# 19           BGR          COK          None         Varna
#
#             partner_port reporter_gateway_iso3 partner_gateway_iso3  \
# 0   Malongo Oil Terminal                  None                  NaN
# 1                 Durres                  None                  NaN
# 2            Al Fujayrah                  None                  NaN
# 3           Buenos Aires                  None                  NaN
# 4           Bandar Abbas                  None                  IRN
# 5               St Johns                  None                  NaN
# 6              Fremantle                  None                  NaN
# 7           Novorossiysk                  None                  RUS
# 8              Antwerpen                  None                  NaN
# 9             Chittagong                  None                  NaN
# 10           Mina Salman                  None                  NaN
# 11                Nassau                  None                  NaN
# 12           Belize City                  None                  NaN
# 13               Tubarao                  None                  NaN
# 14            Bridgetown                  None                  NaN
# 15              Argentia                  None                  NaN
# 16       Puerto Williams                  None                  NaN
# 17      Tianjin Xin Gang                  None                  NaN
# 18                Douala                  None                  NaN
# 19                Avatiu                  None                  NaN
#
#    reporter_basin           partner_basin  distance_km  sea_distance_km  \
# 0       BLACK_SEA          SOUTH_ATLANTIC      5637.60         10491.86
# 1       BLACK_SEA           MEDITERRANEAN       730.70          1586.65
# 2       BLACK_SEA            INDIAN_OCEAN      3264.57          6930.99
# 3       BLACK_SEA          SOUTH_ATLANTIC     12287.08         13526.48
# 4       BLACK_SEA            INDIAN_OCEAN      3100.38          7003.54
# 5       BLACK_SEA               CARIBBEAN      8701.01          9593.88
# 6       BLACK_SEA            INDIAN_OCEAN     12212.65         13871.09
# 7       BLACK_SEA               BLACK_SEA       803.61           849.49
# 8       BLACK_SEA   NORTH_ATLANTIC_EUROPE      1980.03          6136.35
# 9       BLACK_SEA            INDIAN_OCEAN      6242.61         10533.52
# 10      BLACK_SEA                    GULF      2786.67          7605.24
# 11      BLACK_SEA  NORTH_AMERICA_ATLANTIC      9268.99         10626.35
# 12      BLACK_SEA               CARIBBEAN     10650.23         12010.67
# 13      BLACK_SEA          SOUTH_ATLANTIC      9901.92         10874.91
# 14      BLACK_SEA  NORTH_AMERICA_ATLANTIC      8823.10          9653.40
# 15      BLACK_SEA  NORTH_AMERICA_ATLANTIC      6126.62          8032.73
# 16      BLACK_SEA          SOUTH_ATLANTIC     14113.32         15590.78
# 17      BLACK_SEA         WESTERN_PACIFIC      7163.86         16346.71
# 18      BLACK_SEA                ATLANTIC      4709.90          9958.72
# 19      BLACK_SEA   SOUTH_AMERICA_PACIFIC     17467.07         22445.57
#
#     sea_distance_direct_km  sea_distance_forced_km first_chokepoint  \
# 0                 10491.86                10491.86  Turkish Straits
# 1                  1586.65                 1586.65  Turkish Straits
# 2                  6930.99                 6930.99  Turkish Straits
# 3                 13526.48                13526.48  Turkish Straits
# 4                  7003.54                 7003.54  Turkish Straits
# 5                  9593.88                 9593.88  Turkish Straits
# 6                 13871.09                13871.09  Turkish Straits
# 7                   849.49                     NaN              NaN
# 8                  6136.35                 6136.35  Turkish Straits
# 9                 10533.52                10533.52  Turkish Straits
# 10                 7605.24                 7605.24  Turkish Straits
# 11                10626.35                10626.35  Turkish Straits
# 12                12010.67                12010.67  Turkish Straits
# 13                10874.91                10874.91  Turkish Straits
# 14                 9653.40                 9653.40  Turkish Straits
# 15                 8032.73                 8032.73  Turkish Straits
# 16                15590.78                15590.78  Turkish Straits
# 17                16346.71                16346.71  Turkish Straits
# 18                 9958.72                 9958.72  Turkish Straits
# 19                21333.76                22445.57  Turkish Straits
#
#      last_chokepoint                                chokepoint_sequence  \
# 0   Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 1    Turkish Straits                                  [Turkish Straits]
# 2      Bab el-Mandeb       [Turkish Straits, Suez Canal, Bab el-Mandeb]
# 3   Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 4      Bab el-Mandeb       [Turkish Straits, Suez Canal, Bab el-Mandeb]
# 5   Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 6      Bab el-Mandeb       [Turkish Straits, Suez Canal, Bab el-Mandeb]
# 7                NaN                                                 []
# 8   Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 9      Bab el-Mandeb       [Turkish Straits, Suez Canal, Bab el-Mandeb]
# 10     Hormuz Strait  [Turkish Straits, Suez Canal, Bab el-Mandeb, H...
# 11  Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 12  Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 13  Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 14  Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 15  Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 16  Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 17    Malacca Strait  [Turkish Straits, Suez Canal, Bab el-Mandeb, M...
# 18  Gibraltar Strait                [Turkish Straits, Gibraltar Strait]
# 19    Malacca Strait  [Turkish Straits, Suez Canal, Bab el-Mandeb, M...
#
#                               chokepoint_sequence_str headline_exposure_group  \
# 0                 Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 1                                     Turkish Straits  BLACK_SEA_EXIT_EXPOSED
# 2      Turkish Straits -> Suez Canal -> Bab el-Mandeb            SUEZ_EXPOSED
# 3                 Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 4      Turkish Straits -> Suez Canal -> Bab el-Mandeb            SUEZ_EXPOSED
# 5                 Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 6      Turkish Straits -> Suez Canal -> Bab el-Mandeb            SUEZ_EXPOSED
# 7                                                 NaN      BLACK_SEA_REGIONAL
# 8                 Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 9      Turkish Straits -> Suez Canal -> Bab el-Mandeb            SUEZ_EXPOSED
# 10  Turkish Straits -> Suez Canal -> Bab el-Mandeb...          HORMUZ_EXPOSED
# 11                Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 12                Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 13                Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 14                Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 15                Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 16                Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 17  Turkish Straits -> Suez Canal -> Bab el-Mandeb...            SUEZ_EXPOSED
# 18                Turkish Straits -> Gibraltar Strait       GIBRALTAR_EXPOSED
# 19  Turkish Straits -> Suez Canal -> Bab el-Mandeb...            SUEZ_EXPOSED
#
#     main_chokepoint             route_group         route_mode route_status  \
# 0   Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 1   Turkish Straits  BLACK_SEA_EXIT_EXPOSED  forced_chokepoint       ROUTED
# 2   Turkish Straits            SUEZ_EXPOSED  forced_chokepoint       ROUTED
# 3   Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 4   Turkish Straits            SUEZ_EXPOSED  forced_chokepoint       ROUTED
# 5   Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 6   Turkish Straits            SUEZ_EXPOSED  forced_chokepoint       ROUTED
# 7               NaN      BLACK_SEA_REGIONAL             direct       ROUTED
# 8   Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 9   Turkish Straits            SUEZ_EXPOSED  forced_chokepoint       ROUTED
# 10  Turkish Straits          HORMUZ_EXPOSED  forced_chokepoint       ROUTED
# 11  Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 12  Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 13  Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 14  Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 15  Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 16  Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 17  Turkish Straits            SUEZ_EXPOSED  forced_chokepoint       ROUTED
# 18  Turkish Straits       GIBRALTAR_EXPOSED  forced_chokepoint       ROUTED
# 19  Turkish Straits            SUEZ_EXPOSED  forced_chokepoint       ROUTED
#
#                                           route_basis route_confidence  \
# 0               SEA_OBSERVED_MOTCODE|default_shortest           medium
# 1               SEA_OBSERVED_MOTCODE|default_shortest           medium
# 2               SEA_OBSERVED_MOTCODE|default_shortest           medium
# 3               SEA_OBSERVED_MOTCODE|default_shortest           medium
# 4   SEA_OBSERVED_MOTCODE|default_shortest|SEA_GATE...              low
# 5               SEA_OBSERVED_MOTCODE|default_shortest           medium
# 6               SEA_OBSERVED_MOTCODE|default_shortest           medium
# 7   SEA_OBSERVED_MOTCODE|default_shortest|SEA_GATE...              low
# 8               SEA_OBSERVED_MOTCODE|default_shortest           medium
# 9               SEA_OBSERVED_MOTCODE|default_shortest           medium
# 10              SEA_OBSERVED_MOTCODE|default_shortest           medium
# 11  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...           medium
# 12              SEA_OBSERVED_MOTCODE|default_shortest           medium
# 13              SEA_OBSERVED_MOTCODE|default_shortest           medium
# 14  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...           medium
# 15  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...           medium
# 16              SEA_OBSERVED_MOTCODE|default_shortest           medium
# 17  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...           medium
# 18  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...           medium
# 19              SEA_OBSERVED_MOTCODE|default_shortest           medium
#
#    route_applicability_status transport_evidence       routing_decision  \
# 0                sea_observed       sea_observed  route_by_observed_sea
# 1                sea_observed       sea_observed  route_by_observed_sea
# 2                sea_observed       sea_observed  route_by_observed_sea
# 3                sea_observed       sea_observed  route_by_observed_sea
# 4                sea_observed       sea_observed  route_by_observed_sea
# 5                sea_observed       sea_observed  route_by_observed_sea
# 6                sea_observed       sea_observed  route_by_observed_sea
# 7                sea_observed       sea_observed  route_by_observed_sea
# 8                sea_observed       sea_observed  route_by_observed_sea
# 9                sea_observed       sea_observed  route_by_observed_sea
# 10               sea_observed       sea_observed  route_by_observed_sea
# 11               sea_observed       sea_observed  route_by_observed_sea
# 12               sea_observed       sea_observed  route_by_observed_sea
# 13               sea_observed       sea_observed  route_by_observed_sea
# 14               sea_observed       sea_observed  route_by_observed_sea
# 15               sea_observed       sea_observed  route_by_observed_sea
# 16               sea_observed       sea_observed  route_by_observed_sea
# 17               sea_observed       sea_observed  route_by_observed_sea
# 18               sea_observed       sea_observed  route_by_observed_sea
# 19               sea_observed       sea_observed  route_by_observed_sea
#
#                 mot_codes_seen    route_scenario  used_transshipment_hub  \
# 0                  0|1000|2100  default_shortest                   False
# 1             0|1000|2100|3200  default_shortest                   False
# 2        0|1000|2100|2200|3200  default_shortest                   False
# 3        0|1000|2100|3100|3200  default_shortest                   False
# 4                  0|2100|3200  default_shortest                   False
# 5                  0|2100|3200  default_shortest                   False
# 6             0|1000|2100|3200  default_shortest                   False
# 7        0|1000|2100|3100|3200  default_shortest                   False
# 8   0|1000|2100|3100|3200|9200  default_shortest                   False
# 9                  0|1000|2100  default_shortest                   False
# 10                 0|2100|3200  default_shortest                   False
# 11                      0|2100  default_shortest                    True
# 12                      0|2100  default_shortest                   False
# 13                 0|1000|2100  default_shortest                   False
# 14                      0|2100  default_shortest                    True
# 15       0|1000|2100|3200|9200  default_shortest                    True
# 16                 0|2100|3200  default_shortest                   False
# 17  0|1000|2100|3100|3200|9200  default_shortest                    True
# 18                      0|2100  default_shortest                    True
# 19                      0|2100  default_shortest                   False
#
#    hub_port hub_iso3 hub_basin  \
# 0       NaN      NaN      None
# 1       NaN      NaN      None
# 2       NaN      NaN      None
# 3       NaN      NaN      None
# 4       NaN      NaN      None
# 5       NaN      NaN      None
# 6       NaN      NaN      None
# 7       NaN      NaN      None
# 8       NaN      NaN      None
# 9       NaN      NaN      None
# 10      NaN      NaN      None
# 11  Piraeus      GRC      None
# 12      NaN      NaN      None
# 13      NaN      NaN      None
# 14  Piraeus      GRC      None
# 15  Piraeus      GRC      None
# 16      NaN      NaN      None
# 17  Piraeus      GRC      None
# 18  Piraeus      GRC      None
# 19      NaN      NaN      None
#
#                                     route_path_coords
# 0   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 1   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 2   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 3   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 4   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 5   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 6   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 7   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 8   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 9   [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 10  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 11  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 12  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 13  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 14  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 15  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 16  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 17  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 18  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# 19  [[28.0956, 43.1484], [28.438708, 43.022658], [...
# /Users/chromazone/Documents/Python/Data Enginering Zoomcamp/Capstone_monthly/data/silver/comtrade/dim_trade_routes.parquet

# %%
# qa checks — includes review-report red-flag pairs
qa_pairs = [
    ("ROU", "BGR"), ("ROU", "UKR"), ("ROU", "GRC"), ("ROU", "ITA"),
    ("BGR", "TUR"), ("BGR", "ROU"), ("BGR", "GRC"), ("BGR", "ITA"),
    ("AUT", "USA"), ("CZE", "CHN"),
    # red-flag pairs from review report
    ("FRA", "ARE"), ("FRA", "IND"), ("FRA", "CHN"),
    ("ESP", "CHN"), ("ESP", "IND"),
    ("ROU", "SAU"), ("FRA", "SAU"),
]

qa_df = (
    dim_trade_routes[
        dim_trade_routes[["reporter_iso3", "partner_iso3"]].apply(tuple, axis=1).isin(qa_pairs)
    ]
    .sort_values(["reporter_iso3", "partner_iso3"])
    .copy()
)

display(
    qa_df[[
        "reporter_iso3", "partner_iso3",
        "reporter_port", "partner_port",
        "reporter_basin", "partner_basin",
        "first_chokepoint", "last_chokepoint",
        "chokepoint_sequence",
        "headline_exposure_group",
        "route_mode", "route_basis", "route_confidence",
        "sea_distance_direct_km", "sea_distance_forced_km",
        "route_scenario",
    ]]
)

# ------------------------------------------------------------
# ASSERTION 1: Europe -> East routes should not default to Panama/Cape
# ------------------------------------------------------------
bad_default_routes = qa_df[
    (qa_df["route_scenario"] == "default_shortest")
    & (
        qa_df["reporter_iso3"].isin(["FRA", "ESP"])
        & qa_df["partner_iso3"].isin(["ARE", "IND", "CHN", "SAU"])
        & qa_df["headline_exposure_group"].isin(["PANAMA_EXPOSED", "CAPE_REROUTED"])
    )
]

if not bad_default_routes.empty:
    display(bad_default_routes)
    raise AssertionError(
        "Default-shortest routing still contains implausible Europe -> East Panama/Cape routes."
    )

# ------------------------------------------------------------
# ASSERTION 2: forced chokepoint routes must have chokepoints
# ------------------------------------------------------------
missing_cp = dim_trade_routes[
    (dim_trade_routes["route_mode"] == "forced_chokepoint")
    & (dim_trade_routes["chokepoint_sequence"].map(lambda x: not isinstance(x, list) or len(x) == 0))
]

if not missing_cp.empty:
    display(missing_cp.head(20))
    raise AssertionError("Forced chokepoint route missing chokepoint_sequence.")

# ------------------------------------------------------------
# ASSERTION 3: very_low confidence should not dominate
# ------------------------------------------------------------
very_low_share = (
    dim_trade_routes["route_confidence"]
    .astype("string")
    .value_counts(normalize=True)
    .get("very_low", 0.0)
)

if very_low_share > 0.25:
    raise AssertionError(
        f"Too many very_low confidence routes: {very_low_share:.2%}"
    )

print("QA checks passed.")
# Out:
#      reporter_iso3 partner_iso3 reporter_port      partner_port  \
# 41             BGR          GRC         Varna          Piraievs
# 52             BGR          ITA         Varna          Brindisi
# 89             BGR          ROU         Varna            Galati
# 106            BGR          TUR         Varna            Samsun
# 611            ESP          CHN     Barcelona  Tianjin Xin Gang
# 658            ESP          IND     Barcelona            Mundra
# 761            FRA          ARE        Toulon       Al Fujayrah
# 793            FRA          CHN        Toulon  Tianjin Xin Gang
# 845            FRA          IND        Toulon            Mundra
# 911            FRA          SAU        Toulon              Duba
# 1483           ROU          BGR        Galati             Varna
# 1518           ROU          GRC        Galati          Piraievs
# 1530           ROU          ITA        Galati          Brindisi
# 1571           ROU          SAU        Galati            Jiddah
# 1587           ROU          UKR        Galati        Illichivsk
#
#      reporter_basin    partner_basin first_chokepoint  last_chokepoint  \
# 41        BLACK_SEA    MEDITERRANEAN  Turkish Straits  Turkish Straits
# 52        BLACK_SEA    MEDITERRANEAN  Turkish Straits  Turkish Straits
# 89        BLACK_SEA        BLACK_SEA              NaN              NaN
# 106       BLACK_SEA        BLACK_SEA              NaN              NaN
# 611   MEDITERRANEAN  WESTERN_PACIFIC       Suez Canal   Malacca Strait
# 658   MEDITERRANEAN      ARABIAN_SEA       Suez Canal    Bab el-Mandeb
# 761   MEDITERRANEAN     INDIAN_OCEAN       Suez Canal    Bab el-Mandeb
# 793   MEDITERRANEAN  WESTERN_PACIFIC       Suez Canal   Malacca Strait
# 845   MEDITERRANEAN      ARABIAN_SEA       Suez Canal    Bab el-Mandeb
# 911   MEDITERRANEAN          RED_SEA       Suez Canal       Suez Canal
# 1483      BLACK_SEA        BLACK_SEA              NaN              NaN
# 1518      BLACK_SEA    MEDITERRANEAN  Turkish Straits  Turkish Straits
# 1530      BLACK_SEA    MEDITERRANEAN  Turkish Straits  Turkish Straits
# 1571      BLACK_SEA          RED_SEA  Turkish Straits       Suez Canal
# 1587      BLACK_SEA        BLACK_SEA              NaN              NaN
#
#                               chokepoint_sequence headline_exposure_group  \
# 41                              [Turkish Straits]  BLACK_SEA_EXIT_EXPOSED
# 52                              [Turkish Straits]  BLACK_SEA_EXIT_EXPOSED
# 89                                             []      BLACK_SEA_REGIONAL
# 106                                            []      BLACK_SEA_REGIONAL
# 611   [Suez Canal, Bab el-Mandeb, Malacca Strait]            SUEZ_EXPOSED
# 658                   [Suez Canal, Bab el-Mandeb]            SUEZ_EXPOSED
# 761                   [Suez Canal, Bab el-Mandeb]            SUEZ_EXPOSED
# 793   [Suez Canal, Bab el-Mandeb, Malacca Strait]            SUEZ_EXPOSED
# 845                   [Suez Canal, Bab el-Mandeb]            SUEZ_EXPOSED
# 911                                  [Suez Canal]            SUEZ_EXPOSED
# 1483                                           []      BLACK_SEA_REGIONAL
# 1518                            [Turkish Straits]  BLACK_SEA_EXIT_EXPOSED
# 1530                            [Turkish Straits]  BLACK_SEA_EXIT_EXPOSED
# 1571                [Turkish Straits, Suez Canal]            SUEZ_EXPOSED
# 1587                                           []      BLACK_SEA_REGIONAL
#
#              route_mode                                        route_basis  \
# 41    forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 52    forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 89               direct              SEA_OBSERVED_MOTCODE|default_shortest
# 106              direct              SEA_OBSERVED_MOTCODE|default_shortest
# 611   forced_chokepoint  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...
# 658   forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 761   forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 793   forced_chokepoint  SEA_OBSERVED_MOTCODE|default_shortest|OPTIONAL...
# 845   forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 911   forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 1483             direct              SEA_OBSERVED_MOTCODE|default_shortest
# 1518  forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 1530  forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 1571  forced_chokepoint              SEA_OBSERVED_MOTCODE|default_shortest
# 1587             direct              SEA_OBSERVED_MOTCODE|default_shortest
#
#      route_confidence  sea_distance_direct_km  sea_distance_forced_km  \
# 41             medium                  948.26                  948.26
# 52             medium                 1562.94                 1562.94
# 89             medium                  157.38                     NaN
# 106            medium                  819.95                     NaN
# 611            medium                17554.36                17554.36
# 658            medium                 8503.03                 8503.03
# 761            medium                 7922.33                 7922.33
# 793            medium                17338.05                17338.05
# 845            medium                 8286.72                 8286.72
# 911            medium                 3276.85                 3276.85
# 1483           medium                  157.38                     NaN
# 1518           medium                 1002.83                 1002.83
# 1530           medium                 1617.51                 1617.51
# 1571           medium                 3166.44                 3166.44
# 1587           medium                  282.90                     NaN
#
#         route_scenario
# 41    default_shortest
# 52    default_shortest
# 89    default_shortest
# 106   default_shortest
# 611   default_shortest
# 658   default_shortest
# 761   default_shortest
# 793   default_shortest
# 845   default_shortest
# 911   default_shortest
# 1483  default_shortest
# 1518  default_shortest
# 1530  default_shortest
# 1571  default_shortest
# 1587  default_shortest
# QA checks passed.

# %%
# visualize a sample of computed routes on an interactive map
sample_size = 30
plot_df = dim_trade_routes[
    dim_trade_routes["route_path_coords"].map(lambda x: isinstance(x, list) and len(x) > 1)
].head(sample_size).copy()

if plot_df.empty:
    print("No route geometries available to plot.")
else:
    route_map = folium.Map(location=[20, 0], zoom_start=2, tiles="CartoDB positron")

    for row in plot_df.itertuples(index=False):
        coords_latlon = [[pt[1], pt[0]] for pt in row.route_path_coords]
        color = "#d62728" if row.route_mode == "forced_chokepoint" else "#1f77b4"
        popup = (
            f"{row.reporter_iso3} ({row.reporter_port}) -> {row.partner_iso3} ({row.partner_port})<br>"
            f"mode={row.route_mode}, cp={row.main_chokepoint}, scenario={row.route_scenario}<br>"
            f"sea_km={row.sea_distance_km}, basis={row.route_basis}"
        )

        folium.PolyLine(coords_latlon, color=color, weight=2, opacity=0.75, popup=popup).add_to(route_map)

    route_map

# %%
dim_trade_routes_new.query("reporter_iso3 in ['CHN', 'USA', 'FRA']")[
    ["reporter_iso3", "partner_iso3", "transport_evidence", "routing_decision", "route_basis", "route_status"]
].head(50)
# Out:
#     reporter_iso3 partner_iso3 transport_evidence    routing_decision  \
# 119           CHN          ABW  transport_unknown  route_by_inference
# 120           CHN          AGO  transport_unknown  route_by_inference
# 121           CHN          ALB  transport_unknown  route_by_inference
# 122           CHN          ARE  transport_unknown  route_by_inference
# 123           CHN          ARG  transport_unknown  route_by_inference
# 124           CHN          ATG  transport_unknown  route_by_inference
# 125           CHN          AUS  transport_unknown  route_by_inference
# 126           CHN          BEL  transport_unknown  route_by_inference
# 127           CHN          BEN  transport_unknown  route_by_inference
# 128           CHN          BGD  transport_unknown  route_by_inference
# 129           CHN          BGR  transport_unknown  route_by_inference
# 130           CHN          BHR  transport_unknown  route_by_inference
# 131           CHN          BHS  transport_unknown  route_by_inference
# 132           CHN          BIH  transport_unknown  route_by_inference
# 133           CHN          BLZ  transport_unknown  route_by_inference
# 134           CHN          BMU  transport_unknown  route_by_inference
# 135           CHN          BRA  transport_unknown  route_by_inference
# 136           CHN          BRB  transport_unknown  route_by_inference
# 137           CHN          BRN  transport_unknown  route_by_inference
# 138           CHN          CAN  transport_unknown  route_by_inference
# 139           CHN          CHL  transport_unknown  route_by_inference
# 140           CHN          CHN  transport_unknown  route_by_inference
# 141           CHN          CIV  transport_unknown  route_by_inference
# 142           CHN          CMR  transport_unknown  route_by_inference
# 143           CHN          COD  transport_unknown  route_by_inference
# 144           CHN          COG  transport_unknown  route_by_inference
# 145           CHN          COK  transport_unknown  route_by_inference
# 146           CHN          COL  transport_unknown  route_by_inference
# 147           CHN          COM  transport_unknown  route_by_inference
# 148           CHN          CPV  transport_unknown  route_by_inference
# 149           CHN          CRI  transport_unknown  route_by_inference
# 150           CHN          CUB  transport_unknown  route_by_inference
# 151           CHN          CYM  transport_unknown  route_by_inference
# 152           CHN          CYP  transport_unknown  route_by_inference
# 153           CHN          DEU  transport_unknown  route_by_inference
# 154           CHN          DJI  transport_unknown  route_by_inference
# 155           CHN          DMA  transport_unknown  route_by_inference
# 156           CHN          DNK  transport_unknown  route_by_inference
# 157           CHN          DOM  transport_unknown  route_by_inference
# 158           CHN          DZA  transport_unknown  route_by_inference
# 159           CHN          ECU  transport_unknown  route_by_inference
# 160           CHN          EGY  transport_unknown  route_by_inference
# 161           CHN          ERI  transport_unknown  route_by_inference
# 162           CHN          ESP  transport_unknown  route_by_inference
# 163           CHN          EST  transport_unknown  route_by_inference
# 164           CHN          FIN  transport_unknown  route_by_inference
# 165           CHN          FJI  transport_unknown  route_by_inference
# 166           CHN          FRA  transport_unknown  route_by_inference
# 167           CHN          FRO  transport_unknown  route_by_inference
# 168           CHN          FSM  transport_unknown  route_by_inference
#
#                                            route_basis route_status
# 119  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 120  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 121  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 122  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 123  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 124  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 125  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 126  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 127  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 128  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 129  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 130  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 131  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 132  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 133  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 134  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 135  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 136  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 137  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 138  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 139  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 140  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 141  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 142  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 143  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 144  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 145  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 146  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 147  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 148  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 149  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 150  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 151  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 152  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 153  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 154  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 155  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 156  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 157  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 158  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 159  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 160  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 161  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 162  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 163  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 164  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 165  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 166  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 167  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED
# 168  SEA_INFERRED_FROM_UNKNOWN_TRANSPORT|default_sh...       ROUTED

# %%
dim_trade_routes_new["routing_decision"].value_counts(dropna=False)
# Out:
# routing_decision
# route_by_observed_sea    1373
# route_by_inference        900
# Name: count, dtype: int64
